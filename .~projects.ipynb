# %%
print('vfff')
# Out:
# vfff

# %%
import bs4

# %%
lis = ['desw','vfv','vfsf']

# %%
pip install "pandas<2.2.0" "numpy<2.0"
# Out:
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.5 MB 7.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/10.5 MB 11.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/10.5 MB 11.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/10.5 MB 6.7 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/10.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.6/10.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.5 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.5 MB 3.6 MB/s eta 0:00:01
# ...

# %%
import numpy
import pandas as pd

print("NumPy version:", numpy.__version__)
print("Pandas version:", pd.__version__)
# Out:
# NumPy version: 1.26.4
# Pandas version: 2.1.4

# %%
NumPy version: 1.26.4
Pandas version: 2.1.4

# %%
import pandas as p

# %%
data = p.read_csv("C:\\Users\\sampar\\Downloads\\Recipe manager idea.csv")

# %%
print(data)
# Out:
#    SL-no           Recipe Name                                 Ingredients  \
# 0      1  Paneer Butter Masala       Paneer, Tomato, Butter, Cream, Spices
# 1      2          Chole Masala            Chickpeas, Onion, Tomato, Spices
# 2      3             Aloo Gobi  Potato, Cauliflower, Onion, Tomato, Spices
# 3      4        Butter Chicken      Chicken, Butter, Tomato, Cream, Spices
# 4      5           Masala Dosa              Rice, Urad Dal, Potato, Spices
# 5      6     Vegetable Biryani                 Rice, Mixed Veggies, Spices
# 6      7            Rogan Josh       Mutton, Yogurt, Onion, Tomato, Spices
# 7      8                Samosa                 Potato, Peas, Flour, Spices
# 8      9          Palak Paneer      Spinach, Paneer, Onion, Garlic, Spices
# 9     10             Dal Tadka      Lentils, Onion, Tomato, Garlic, Spices
#
#   Preparation Time        Type
# 0           30 min  Vegetarian
# 1           40 min  Vegetarian
# 2           25 min  Vegetarian
# ...

# %%
search_column = 'Recipe Name'
sl = 'SL-no'
search = input('pls enter the recipe you want')
for idx,row in data.iterrows():
    if row[search_column]==search:
        print(idx)
        print(row)
# Out:
# pls enter the recipe you want Dal Tadka
# 9
# SL-no                                                   10
# Recipe Name                                      Dal Tadka
# Ingredients         Lentils, Onion, Tomato, Garlic, Spices
# Preparation Time                                    25 min
# Type                                            Vegetarian
# Name: 9, dtype: object
# SL-no

# %%
data.add()

# %%
import pandas as pd

# Load your CSV
df = pd.read_csv('recipes.csv')

# Column to search in
search_col = 'Recipe_Name'

# Ask user for search term
search = input("Enter recipe name: ").strip().lower()

# Loop through rows to find it
for idx, row in df.iterrows():
    if str(row[search_col]).lower() == search:
        # Current row
        print("Found recipe row:")
        print(row)
        
        # Next row (if exists)
        if idx + 1 < len(df):
            print("\nNext row (likely ingredients):")
            print(df.iloc[idx + 1])
        break
else:
    print("Recipe not found")

# %%
with open('prac.csv','a+',encoding='utf-8') as f:
    f_csv = csv.writer(f)
    i=0
    f_csv.writerow([str(i),'','','','','','','','',''])

# %%
import csv

# %%
f.close()

# %%
help(pandas)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
--ServerApp.iopub_data_rate_limit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 --ServerApp.iopub_data_rate_limit
#
# NameError: name 'ServerApp' is not defined

# %%
pip install ServerApp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ServerApp from https://files.pythonhosted.org/packages/36/85/706277ad0f73d30bd6e2fd0d987e18636760059c626cc1a217d9197cacf1/serverapp-0.1.tar.gz does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
p = 21
print('vfdv',p,'vfdv')

# %%
class alarm_clock

# %%
import datetime

# %%
date_time = datetime.datetime.today()

# %%
date_time = datetime.datetime.today()
date_time.time()
date_time.minute
min_r_hour = input('Do you want to set alarm for Minutes or Hours (min/Hour): \n').lower()
print('Note: Till 59 minutes only you can keep. ')
if min_r_hour == 'min':
    date_time = datetime.datetime.today()
    date_time.time()
    min = date_time.minute
    hour = date_time.hour
    print('hour:',hour)
    alarm_min = int(input('So after how many minutes alarm should go: '))
    total = alarm_min-cal
    print(total)
    if alarm_min>cal :
        cal = 60-min
        cal
        hour = hour + 1
        total = alarm_min-cal
    else:
        total = min + alarm_min
    print(f'Your Alarm goes off at {hour}:{total}')
alarm_min = int(input('So after how many minutes alarm should go: '))
hour = date_time.hour 
min = date_time.minute

total = min + alarm_min

if 5<hour<0:
    period_of_day == 'Morning'
elif 12<hour<17:
    period_of_day == 'Afternoon'
elif 17<hour<21:
    period_of_day == 'Evening'
elif 21<hour<0:
    period_of_day == 'Night'
print(f'now the Time is {period_of_day} {hour}:{min} ')

print()f'So your alarm goes off after '
print(f'your alarm goes after {alarm_min} minutes')

# %%
date_time = datetime.datetime.today()
date_time.time()
min = date_time.minute
hour = date_time.hour
print('hour:',hour)

# %%
import datetime

# %%
date_time = datetime.datetime.today()
date_time.time()
min = date_time.minute
hour = date_time.hour
print('hour:',hour)
alarm_min = int(input('So after how many minutes alarm should go: '))
cal = 60-min
cal
total = alarm_min-cal
print(total)
if alarm_min>cal :
    hour = hour + 1
    total = alarm_min-cal
    n=0
    while total>60:
        hour = hour+1
        total = total-60
        n=n+1
    if hour>23:
        hour = 0
else:
    total = min + alarm_min
print(f'Your Alarm goes off at {hour}:{total}')
# Out:
# hour: 17
# So after how many minutes alarm should go:  1
# -3
# Your Alarm goes off at 17:57

# %%
# 52

# %%
r = range(60)
if r == 60:
    r = 0
r = date_time.minute
r = 
if r<59:
    c = 59-r
total = (0+c)
print(total)

# %%
67
o= 0<y>60

# %%
# !pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
# ...

# %%
import pygame
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def recipe_name():
    m_c_k = [
        "rice","bread","curries","noodles pasta","noodles","complete meals","meat dishes","international",
        "biryani", "pulao", "fried rice", "khichdi", "curd rice", "jeera rice",
        "bread", "roti", "chapati", "naan", "paratha", "kulcha", "bhatura", "puri",
        "curries", "dal", "chicken curry", "mutton curry", "paneer butter masala",
        "chole", "rajma", "sambar", "fish curry", "korma", "egg curry",
        "noodles", "chowmein", "ramen", "spaghetti", "pasta", "lasagna",
        "thali", "dal chawal", "idli sambar", "dosa", "uttapam", "pongal",
        "upma", "kadhi chawal", "khichdi",
        "butter chicken", "tandoori chicken", "biryani", "mutton biryani",
        "kebabs (meal sized)", "fish fry with rice",
        "pizza", "burger", "taco", "burrito", "quesadilla", "shawarma",
        "sushi (meal set)", "steak", "casserole"
    ]
    d_k = [
        # Indian sweets
        "sweets","sweet",
        "halwa", "kheer", "payasam", "rasgulla", "gulab jamun", "jalebi",
        "laddu", "ladoo", "barfi", "burfi", "peda", "sandesh", "mysore pak",
        "soan papdi", "cham cham", "shrikhand", "malpua", "rabri", "kulfi",
        "phirni", "modak", "gujiya", "sheera", "seviyan", "balushahi",
        
        # Cakes & pastries
        "cake", "cupcake", "brownie", "pastry", "muffin", "cheesecake",
        "sponge cake", "red velvet", "black forest", "fruit cake",
        
        # Frozen desserts
        "ice cream", "gelato", "sorbet", "kulfi", "popsicle", "falooda",
        "sundae", "frozen yogurt",
        
        # Pies & tarts
        "pie", "apple pie", "pumpkin pie", "pecan pie", "tart", "custard tart",
        "fruit tart",
        
        # Puddings & custards
        "pudding", "caramel pudding", "chocolate pudding", "custard", "mousse",
        "souffle", "trifle",
        
        # Confectionery
        "chocolate", "fudge", "candy", "toffee", "marshmallow", "macaron",
        "donut", "doughnut", "waffle", "pancake", "crepe", "churros", "eclair",
        "profiterole"
    ]
    s_k = [
        # Indian vegetables & fruits
        "cucumber", "tomato", "onion", "carrot", "beetroot", "cabbage",
        "radish", "capsicum", "pomegranate", "apple", "banana", "grapes",
        "orange", "papaya", "moong dal", "chana", "sprouts", "corn",
        "curd", "yogurt", "paneer", "lemon", "coriander", "mint",
        "chat masala", "salt",
    
        # Global vegetables
        "artichoke", "asparagus", "broccoli", "cauliflower", "spinach",
        "lettuce", "kale", "potato", "sweet potato", "okra",
        "eggplant", "zucchini", "bell pepper", "mushroom", "celery",
        "pea", "bean", "radicchio", "parsnip", "turnip",
    
        # Global fruits
        "mango", "pineapple", "strawberry", "blueberry", "blackberry",
        "raspberry", "pear", "peach", "plum", "cherry", "kiwi",
        "watermelon", "melon", "guava", "lychee", "dragon fruit",
        "fig", "dates", "apricot", "passion fruit",
     "kosambari", "kachumber", "raita", "boondi raita", "vegetable raita", "fruit raita",
        "pachadi", "thayir pachadi", "avial salad style",  
        "sprout salad", "moong dal salad", "corn chaat", "fruit chaat",
        "veg chaat", "green salad", "mixed veg salad", "beetroot salad",  
        "paneer salad", "curd salad", "yogurt salad", "onion salad", "cabbage salad", 
     "kachumber", "laccha pyaaz", "raita", "boondi raita", "fruit raita", "paneer raita",
        "pachadi", "thayir pachadi", "kosambari", "kosumalli", "singju",
        "kala chana salad", "sprouted moong salad", "roasted peanut salad",
        "beetroot carrot kosambari", "cabbage & curd mix", "fruit chaat",
        "chickpea salad"
    ]  
    st_k = [
        # Indian veg fritters & variations
        "pakora", "pakoda", "bhaji", "bhajji", "bonda", "bajji", "vada", "vadai",
        "methi pakora", "palak pakora", "mirchi pakora", "mirchi bajji",
        "onion pakora", "onion pakoda", "onion bhaji", "onion bhajji",
    
        # Popular Indian vegetarian starters
        "aloo tikki", "samosa", "paneer tikka", "paneer pakora", "paneer pakoda",
        "paneer 65", "paneer manchurian", "veg cutlet", "veg spring roll",
        "veg manchurian", "momos", "veg momos", "hara bhara kabab",
        "dhokla", "khandvi", "sev puri", "pani puri", "golgappa", "phuchka", "gupchup", "batasha",
        "dahi puri", "bhel puri", "papdi chaat", "chaat", "masala papad",
        "corn tikki", "stuffed paneer", "tandoori mushroom", "baby corn manchurian", "gobi manchurian",
    
        # South Indian snacks (often served as starters)
        "medu vada", "mendu vada", "methu vada", "masala vada", "paruppu vadai",
        "idli fry", "mini idli", "punugulu", "mysore bonda",
    
        # Indian non-veg starters
        "chicken tikka", "tandoori chicken", "chicken lollipop",
        "chicken pakora", "chicken pakoda", "chicken 65", "dragon chicken",
        "pepper chicken", "seekh kabab", "shami kabab", "reshmi kabab",
        "malai tikka", "kalmi kabab", "mutton kabab", "mutton seekh",
        "fish pakora", "fish pakoda", "fish fry", "fish tikka",
        "prawn fry", "tandoori prawns",
        "egg pakora", "egg pakoda", "egg bajji", "egg cutlet", "egg kebab",
        "chicken wings", "buffalo wings",
    
        # International starters
        "french fries", "garlic bread", "bruschetta", "nachos", "stuffed mushrooms",
        "mozzarella sticks", "cheese balls", "jalapeno poppers", "deviled eggs",
        "mini quiche", "dumplings", "spring rolls", "onion rings",
        "tacos (starter size)", "quesadilla (small)",
    ]
    snacks_k = [
    # south india
    "punugulu", "mirchi bajji", "bobbattu", "garelu", "aratikaya bajji",
    "mysore bonda", "maddur vada", "churmuri", "neer dosa", "ragi murukku",
    "vada pav", "pav bhaji", "kanda bhaji", "misal pav", "shankarpali",
    "murukku", "sundal", "vadai", "bajji", "kozhukattai",
    "banana chips", "pazham pori", "unni appam", "achappam", "kozhukatta",
    "sarva pindi", "pesarattu", "osmania biscuit", "mirchi bajji",

    # north india
    "samosa", "aloo tikki", "bedmi poori", "kachori", "pani puri", "gol gappa",
    "papdi chaat", "bhel puri", "sev puri", "chole kulche",
    "pyaz kachori", "mirchi vada", "bikaneri bhujia",
    "amritsari fish fry", "bread pakora", "chole bhature",
    "kathi roll", "telebhaja", "shingara", "phuchka", "jhalmuri",
    "pakora", "poha", "dahi vada", "aloo chaat",

    # east india
    "litti chokha", "thekua", "ghugni", "muri mixture",
    "chakuli pitha", "gulgula
    ]
    beverages_k = [
        # 🧋 North India
        "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
        "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
        "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
        "gur ka sharbat", "ganne ka juice", "sugarcane juice",
        
        # 🍶 West India
        "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
        "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
        "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
        
        # ☕ South India
        "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
        "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
        "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
        "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
        
        # 🍵 East India
        "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
        "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
        "banta soda", "sugarcane juice", "nolen gur milkshake",
        
        # 🍸 Central & Tribal India
        "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
        "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
        
        # 🧃 Pan-India Popular Beverages
        "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
        "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
        "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
        "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
        
        # 🥛 Modern / Street & Fusion Drinks
        "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
        "falooda", "dry fruit shake", "cold cocoa", "rabri falooda", "paan shot",
        
        # 🍹 Festival & Ayurvedic Beveragesbeverages_k = beverages_india = [
        # 🧋 North India
        "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
        "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
        "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
        "gur ka sharbat", "ganne ka juice", "sugarcane juice",
        
        # 🍶 West India
        "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
        "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
        "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
        
        # ☕ South India
        "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
        "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
        "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
        "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
        
        # 🍵 East India
        "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
        "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
        "banta soda", "sugarcane juice", "nolen gur milkshake",
        
        # 🍸 Central & Tribal India
        "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
        "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
        
        # 🧃 Pan-India Popular Beverages
        "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
        "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
        "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
        "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
        
        # 🥛 Modern / Street & Fusion Drinks
        "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
        "thandai", "holi thandai", "kanji", "sattu drink", "panchamrit", "amrit tulsi tea",
        "turmeric milk", "golden milk", "kadha", "herbal decoction", "neem juice"
    
         # North India
        "lassi, lah-si",
        "chhach, chaach",
        "sattu sharbat, sut-too shar-bat",
        "thandai, thun-dai",
        "kesar doodh, kay-sar Doodh",
        "noon chai, noon chaai",
        "kahwa, kaa-va",
        "kanji, kaan-jee",
    
        # West India
        "Solkadhi, Sol-ka-dhi",
        "Aam Panna, Aam Pan-na",
        "Piyush, Pee-yush",
        "Feni, Feh-nee",
        "Kokum Sherbet, Ko-kum Sher-bet",
        "Kesar Kasturi Doodh, Kay-sar Kas-too-ree Doodh",
        "Chaas, Chaas",
    
        # South India
        "Filter Coffee, Filter Kaapi",
        "Jigarthanda, Ji-gar-than-da",
        "Majjige, Maj-ji-gay",
        "Panakam, Paa-na-kam",
        "Tender Coconut Water, Elaneer",
        "Ragi Malt, Raa-gee Malt",
        "Sukku Coffee, Sook-ku Kaapi",
    
        # East India
        "Borhani, Bor-ha-nee",
        "Handia, Han-dee-ya",
        "Mahua, Ma-hoo-aa",
        "Apong, Ah-pong",
        "Xaj Pani, Haaj Pani",
        "Sabja Sharbat, Sub-ja Shar-bat",
    
        # NorthEast Tribal
        "Zutho, Zoo-tho",
        "Thuthse, Thoot-say",
        "Yu, Yoo",
        "Tongba, Tong-baa",
        "Ki Kiad, Kee Kee-ad",
    
        # Pan India Common
        "Chai, Chaai",
        "Masala Chai, Masa-laa Chaai",
        "Nimbu Pani, Nim-boo Paa-nee",
        "Sugarcane Juice, Ganne ka Ras",
        "Badam Milk, Baa-daam Milk",
        "Rose Sharbat, Roaz Shar-bat",
        "Falooda, Fa-loo-daa"
    ]
    beverage_pronunciation = {
        # North India
        "lassi": "Lah-si",
        "chhach": "Chaach",
        "sattu sharbat": "Sut-too Shar-bat",
        "thandai": "Thun-dai",
        "kesar doodh": "Kay-sar Doodh",
        "noon chai": "Noon Chaai",
        "kahwa": "Kaa-va",
        "kanji": "Kaan-jee",
        "nimbu pani": "Nim-boo Paa-nee",
        "rose sharbat": "Roaz Shar-bat",
        "badam milk": "Baa-daam Milk",
        "falooda": "Fa-loo-daa",
    
        # West India
        "solkadhi": "Sol-ka-dhi",
        "aam panna": "Aam Pan-na",
        "piyush": "Pee-yush",
        "feni": "Feh-nee",
        "kokum sharbat": "Ko-kum Shar-bet",
        "kesar kasturi doodh": "Kay-sar Kas-too-ree Doodh",
        "chaas": "Chaas",
    
        # South India
        "filter coffee": "Filter Kaapi",
        "jigarthanda": "Ji-gar-than-da",
        "majige": "Maj-ji-gay",
        "panakam": "Paa-na-kam",
        "tender coconut water": "Elaneer",
        "ragi malt": "Raa-gee Malt",
        "sukku coffee": "Sook-ku Kaapi",
    
        # East India
        "borhani": "Bor-ha-nee",
        "handia": "Han-dee-ya",
        "mahua drink": "Ma-hoo-aa",
        "apong": "Ah-pong",
        "xaj pani": "Haaj Pani",
        "sabja sharbat": "sub-ja shar-bat",
    
        # NorthEast Tribal
        "zutho": "Zoo-tho",
        "thuthse": "Thoot-say",
        "yu": "Yoo",
        "tongba": "Tong-baa",
        "ki kiad": "Kee Kee-ad",
    
        # Pan India Common
        "chai": "Chaai",
        "masala chai": "Masa-laa Chaai",
        "sugarcane juice": "Ganne ka Ras",
    }
    break_fast_k = [
        # South India
        "idli", "vada", "pongal", "dosa", "sada dosa", "masala dosa", "uthappam", "puttu", "upma", "appam",
        "palappam", "vellayappam", "idiyappam", "nool puttu", "noolappam", "shavige", "parotta", "pathiri", "pazham pori",
        "masala dosa", "benne dosa", "mysore masala dosa", "set dosa", "rava idli", "akki rotti", "ragi mudde",
        "uppittu", "bisi bele bath", "neer dosa",
        "pesarattu", "mla pesarattu", "upma pesarattu", "dibba rotti", "pulihora", "tamarind rice", "jonna roti", "sajja roti",
    
        # North India
        "paratha", "aloo paratha", "gobi paratha", "paneer paratha", "mooli paratha",
        "poori with aloo sabzi", "chole bhature", "kulcha", "bread pakora",
        "kachori with aloo sabzi", "bedmi poori", "thekua", "jalebi with milk", "puri sabzi",
        "dal baati churma", "mirchi vada", "pyaz kachori", "mawa kachori",
        "litti chokha", "sattu paratha", "chana ghugni with litti",
        "poha jalebi", "samosa", "kachori", "bhutte ka kees",
    
        # West India
        "poha", "kanda poha", "batata poha", "sabudana khichdi", "thalipeeth", "misal pav", "pav", "vada pav",
        "thepla", "fafda jalebi", "khaman dhokla", "handvo", "khakhra", "sev khamani", "patra", "alu vadi",
        "pav with bhaji", "ros omelette", "poi bread with chorizo", "poi bread with vegetable",
    
        # East India
        "luchi with aloor torkari", "radhaballabhi", "chirer polao", "flattened rice", "mughlai paratha",
        "ghugni", "panta bhaat",
        "pakhala bhata", "bara", "chakuli pitha", "enduri pitha", "aloo chop",
        "pitha", "til pitha", "narikol pitha", "chira doi gur", "jolpan",
        "rice with vegetables", "momos", "khasi jadoh", "tungtap",
    
        # Union Territories / Metro Influences
        "french bread", "croissant", "idli", "dosa",
        "cornflakes", "sandwich", "bread butter",
        "parantha with butter and curd",
        "rice", "fish curry", "chapati",
    
        # Common Pan-India Breakfasts
        "idli", "vada", "dosa", "upma", "pongal", "puttu",
        "paratha", "poori sabzi", "kachori sabzi",
        "poha", "chole bhature", "kulcha",
        "bread butter", "bread pakora", "sandwich",
        "tea biscuit", "coffee bun", "milk cornflakes"
    ]
    soups_india = [
        # North India
        "Rasam",
        "Sambar",
        "Mulligatawny Soup",
        "Thukpa",
        "Masor Tenga",
        "Macher Jhol",
        "Khar",
        "Dal Shorba",
        "Tomato Soup",
        "Sweet Corn Soup",
        "Vegetable Soup",
        "Chicken Soup",
        "Mutton Soup",
        "Kadhi",
        "Dal Makhani Soup",
        "Sarson Da Saag Soup",
        "Gatte Ki Sabzi Soup",
        "Kadhi Pakora Soup",
        
        # East India
        "Fish Soup",
        "Prawn Soup",
        "Shutki Fish Soup",
        "Dalma",
        "Machha Besara",
        "Shorshe Ilish Soup",
        
        # West India
        "Maharashtrian Spiced Soup",
        "Pithla Bhakri Soup",
        "Sol Kadhi",
        "Handvo Soup",
        "Bajra Khichdi Soup",
        "Methi Thepla Soup",
        
        # South India
        "Paruppu Rasam",
        "Pepper Rasam",
        "Bisi Bele Bath Soup",
        "Ragi Soup",
        "Vegetable Stew",
        "Meen Curry Soup",
        "Dal Bafla Soup",
        "Poha Soup",
        "Sannas Soup",
        "Caldo Verde",
        "Mulligatawny Soup",  # already in North India, keep only once
        "Sattu Sharbat",
        "Litti Chokha Soup",
        
        # NorthEast / Tribal India
        "Thukpa",  # already in North India
        "Paka Lawa",
        "Eromba Soup",
        "Ooti Soup",
        "Jadoh Soup",
        "Dohneiiong Soup",
        "Bamboo Shoot Soup",
        "Vawksa Rep",
        "Smoked Pork Soup",
        "Zutho Soup",
        "Mui Borok",
        "Wahan Macher Jhol",
        "Sohphie Thukpa",
        "Smoked Meat Soup",
        
        # Pan-India / Popular Indo-Chinese / Fusion
        "Hot & Sour Soup",
        "Lemon Coriander Soup",
        "Manchow Soup",
        "Talumein Soup",
        "Clear Vegetable Soup"
    ]
    

    
    while True:
        print('pls type (over) if u have finished storing everything')
        choice = input('if u want to start, pls type yes: ').lower()
        if choice == 'yes':
            veggies = input('pls enter your recipe [name] ')
            veg = veggies.split()
            
            norm=[]
            print(veg)
            for i in veg:
                if i in m_c_k:
                    norm.append(i)
                    print(f'here are matched words with maincourse{norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in main_course file ')
                        print('Nice,lets start with your ingredients')
                        return 7,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')

                elif i in d_k:
                    norm.append(i)
                    print(f'here are matched words with dessert {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in dessert file ')
                        print('Nice,lets start with your ingredients')
                        return 9,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif i in s_k:
                    norm.append(i)
                    print(f'here are matched words with Salad {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in salads file ')
                        print('Nice,lets start with your ingredients')
                        return 2,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif i in st_k:
                    norm.append(i)
                    print(f'here are matched words with Starter {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in starter file ')
                        print('Nice,lets start with your ingredients')
                        return 1,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')
    

                elif i in break_fast_k:
                    norm.append(i)
                    print(f'here are matched words with break fast {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in break_fast file ')
                        print('Nice,lets start with your ingredients')
                        return 3,veggies
                    else:
            
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif i in snacks_k:
                    norm.append(i)
                    print(f'here are matched words with snacks {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in snacks file ')
                        print('Nice,lets start with your ingredients')
                        return 4,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif i in beverages_k:
                    norm.append(i)
                    print(f'here are matched words with beverages {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in beverages file ')
                        print('Nice,lets start with your ingredients')
                        return 5,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif i in soups_india:
                    norm.append(i)
                    print(f'here are matched words with soups {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in soups file ')
                        print('Nice,lets start with your ingredients')
                        return 6,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')
            print('pls type over if you finished writing ')
            side_dish = input('if it is sidedish pls type (Yes) or (No)').lower()
            if side_dish == 'Yes':
                return 8,veggies
            else:
                print('so its not sidedish')
                print('its not present in our list also')
                print('so pls say if your dishes belong to any of this list [Appetizers/Starters , Salads, Breakfast , Snacks , beverages, Soups, Maincourse,Desserts]')
                print('if not we are adding it to our side dishes column')
                print('pls write your choice')
                choose = input('pls enter can we keep in any list [Appetizers/Starters , Salads, Breakfast , Snacks , beverages, Soups, Maincourse,Desserts]')
                if choose == 'starter':
                    return 1,veggies
                elif choose == 'salad':
                    return 2,veggies
                elif choose == 'breakfast':
                    return 3,veggies
                elif choose == 'snack':
                    return 4,veggies
                elif choose == 'beverage':
                    return 5,veggies
                elif choose == 'soup':
                    return 6,veggies
                elif choose == 'main_courses':
                    return 7,veggies
                elif choose == 'desserts':
                    return 9,veggies
            
        elif choice == 'over':
            print('yes u are quitting now')
            break
    
        else:
            print('if u want to store  pls type according to given instructions')

# %%
recipe_name()
# Out:
# pls type (over) if u have finished storing everything
# if u want to start, pls type yes:  yes
# pls enter your recipe [name]  noodles
# ['noodles']
# here are matched words with maincourse['noodles']
# ['noodles']
# if your recipe is in the above list, pls type (yes)
# if confirmed,pls type (yes) yes
# its confirmed, we will store this in main_course file
# Nice,lets start with your ingredients
# (7, 'noodles')

# %%
def ingredients(self):
    no,recipe_name=recipe_name()
    
    if no==1:
        starter_f=open('starter.csv','a+',encoding='utf-8')
        starters=csv.writer(starter_f)
        while z_1!=1:
            starters.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains , Lentils,Nuts(seeds), Herbs(Aromatics), Spices(Powders), Sauces(Condiments), Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_1=z_1+1
        starters.writerow(['','',recipe_name,'','','','','','','','','','','']])
        st = 'starter'
        recipe_list[recipe_name]= st
        
        prep_time = input('pls enter your preparation time for this dish')
        starters.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg')
        starters.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables, Fruits, Items(Dairy Products & Meat-Seafood & Paclaged Items), Grains, Lentils, Nuts & Seeds, Herbs/Aromatics, Spices/Powders, Sauces/ Condiments, Oils/Fats]').lower()
           
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                starters.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                starters.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                starters.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                starters.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                lentils = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','',lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre== 'over':
                print('thanks for using our code')
                recipe_list = []
                break

    elif no==2:
        salad_f = open('salads.csv','a+',encoding='utf-8')
        salads= csv.writer(salad_f)
        while z_2!=1:
            salads.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains , Lentils,Nuts(seeds), Herbs(Aromatics), Spices(Powders), Sauces(Condiments), Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_2=z_2+1
        salads.writerow(['','',recipe_name,'','','','','','','','','','','']])
        sa = 'salads'
        recipe_list[recipe_name]=sa
        prep_time = input('pls enter your preparation time for this dish')
        salads.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg')
        salads.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            ingre = input('pls say what you would like to enter first in this [Vegetables, Fruits, Items(Dairy Products & Meat-Seafood & Paclaged Items), Grains, Lentils, Nuts & Seeds, Herbs/Aromatics, Spices/Powders, Sauces/ Condiments, Oils/Fats]').lower()
            
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                salads.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                salads.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                salads.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                salads.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==3:
        breakfast_f=open('breakfast.csv','a+',encoding='utf-8')
        breakfast = csv.writer(breakfast_f)
        while z_3!=1:
            breakfast.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_3=z_3+1
        breakfast.writerow(['','',recipe_name,'','','','','','','','','','','']])
        br = 'breakfast'
        recipe_list[recipe_name]=br
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        breakfast.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        breakfast.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                breakfast.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                breakfast.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                lentils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','',lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==4:
        snacks_f=open('snacks.csv','a+',encoding='utf-8')
        snacks = csv.writer(snacks_f)
        while z_4!=1:
            snacks.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_4=z_4+1
        snacks.writerow(['','',recipe_name,'','','','','','','','','','','']])
        sn = 'snacks'
        recipe_list[recipe_name]=sn
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        snacks.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        breakfast.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                snacks.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                snacks.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each item ')
                items = input('so pls enter your fruits: ')
                snacks.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==5:
        beverages_f=open('beverages.csv','a+',encoding='utf-8')
        beverages = csv.writer(beverages_f)
        while z_5!=1:
            beverages.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_5=z_5+1
        beverages.writerow(['','',recipe_name,'','','','','','','','','','','']])
        be='beverages'
        recipe_list[recipe_name]=be
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        beverages.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        beverages.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                beverages.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                beverages.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                beverages.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==6:
        soups_f=open('soups.csv','a+',encoding='utf-8')
        soups = csv.writer(soups_f)
        while z_6!=1:
            soups.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_6=z_6+1
        soups.writerow(['','',recipe_name,'','','','','','','','','','','']])
        so='soups'
        recipe_list[recipe_name]=so
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        soups.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        soups.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                soups.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                soups.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                soups.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                soups.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==7:
        main_courses_f=open('main_courses.csv','a+',encoding='utf-8')
        main_courses = csv.writer(main_courses_f)
        while z_7!=1:
            main_courses.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_7=z_7+1
        main_courses.writerow(['','',recipe_name,'','','','','','','','','','','']])
        mac='main_courses'
        recipe_list[recipe_name]=sa
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        main_courses.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        main_courses.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                main_courses.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                main_courses.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break
    

    elif no==8:
        side_dishes_f=open('side_dishes.csv','a+',encoding='utf-8')
        side_dishes = csv.writer(side_dishes_f)
        while z_8!=1:
            side_dishes.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_8=z_8+1
        side_dishes.writerow(['','',recipe_name,'','','','','','','','','','','']])
        sid='side_dishes'
        recipe_list[recipe_name]=sid
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        side_dishes.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        side_dishes.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                side_dishes.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==9:
        desserts_f=open('desserts.csv','a+',encoding='utf-8')
        desserts = csv.writer(desserts_f)
        
        while z_9!=1:
            desserts.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
            z_9=z_9+1
        desserts.writerow(['','',recipe_name,'','','','','','','','','','','']])
        de = 'desserts'
        recipe_list[recipe_name]=de
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        desserts.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        desserts.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                desserts.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                desserts.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                desserts.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

# %%
def search(self,recipe_name):
    import pandas as p
    category = recipe_list[recipe_name]
    print(f' this recipe belongs to {category}')
    if category == 'starter':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\starter.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)
     elif category == 'salads':
         data = p.read_csv("C:\\Users\\sampar\\python projects\\salads.csv")
         search_col = 'Recipe_Name'
         search_recipe = recipe_name
         for idx,row in data.iterrows():
             if row[search_col]==search_recipe:
                 print(idx)
                 print(row) 

    elif category == 'breakfast':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\breakfast.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row) 

        
    elif category == 'snacks':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\snacks.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)  

    elif category == 'snacks':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\snacks.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)  

    elif category == 'beverages':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\beverages.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)

    elif category == 'main_courses':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\main_courses.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)

    elif category == 'side_dishes':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\side_dishes.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)

    elif category == 'desserts':
        data = p.read_csv("C:\\Users\\sampar\\python projects\\desserts.csv")
        search_col = 'Recipe_Name'
        search_recipe = recipe_name
        for idx,row in data.iterrows():
            if row[search_col]==search_recipe:
                print(idx)
                print(row)

# %%
z=0
while z!=1:
    print('pwoer')
    z=z+1
print('once printed')
# Out:
# pwoer
# once printed

# %%
def spelling(self,recipe_name):
    choice = input('pls input which category you want to display for category')
    if choice == 'starter':
        starters= [ # Indian veg fritters & variations
        "pakora", "pakoda", "bhaji", "bhajji", "bonda", "bajji", "vada", "vadai",
        "methi pakora", "palak pakora", "mirchi pakora", "mirchi bajji",
        "onion pakora", "onion pakoda", "onion bhaji", "onion bhajji",
    
        # Popular Indian vegetarian starters
        "aloo tikki", "samosa", "paneer tikka", "paneer pakora", "paneer pakoda",
        "paneer 65", "paneer manchurian", "veg cutlet", "veg spring roll",
        "veg manchurian", "momos", "veg momos", "hara bhara kabab",
        "dhokla", "khandvi", "sev puri", "pani puri", "golgappa", "phuchka", "gupchup", "batasha",
        "dahi puri", "bhel puri", "papdi chaat", "chaat", "masala papad",
        "corn tikki", "stuffed paneer", "tandoori mushroom", "baby corn manchurian", "gobi manchurian",
    
        # South Indian snacks (often served as starters)
        "medu vada", "mendu vada", "methu vada", "masala vada", "paruppu vadai",
        "idli fry", "mini idli", "punugulu", "mysore bonda",
    
        # Indian non-veg starters
        "chicken tikka", "tandoori chicken", "chicken lollipop",
        "chicken pakora", "chicken pakoda", "chicken 65", "dragon chicken",
        "pepper chicken", "seekh kabab", "shami kabab", "reshmi kabab",
        "malai tikka", "kalmi kabab", "mutton kabab", "mutton seekh",
        "fish pakora", "fish pakoda", "fish fry", "fish tikka",
        "prawn fry", "tandoori prawns",
        "egg pakora", "egg pakoda", "egg bajji", "egg cutlet", "egg kebab",
        "chicken wings", "buffalo wings",
    
        # International starters
        "french fries", "garlic bread", "bruschetta", "nachos", "stuffed mushrooms",
        "mozzarella sticks", "cheese balls", "jalapeno poppers", "deviled eggs",
        "mini quiche", "dumplings", "spring rolls", "onion rings",
        "tacos (starter size)", "quesadilla (small)",   
        ]
        
        print(starter)
        for key,value in recipe_list.items():
            if value=='starter':
                print(key)
    elif choice == 'desserts':
        desserts = [
        # Indian sweets
        "sweets","sweet",
        "halwa", "kheer", "payasam", "rasgulla", "gulab jamun", "jalebi",
        "laddu", "ladoo", "barfi", "burfi", "peda", "sandesh", "mysore pak",
        "soan papdi", "cham cham", "shrikhand", "malpua", "rabri", "kulfi",
        "phirni", "modak", "gujiya", "sheera", "seviyan", "balushahi",
        
        # Cakes & pastries
        "cake", "cupcake", "brownie", "pastry", "muffin", "cheesecake",
        "sponge cake", "red velvet", "black forest", "fruit cake",
        
        # Frozen desserts
        "ice cream", "gelato", "sorbet", "kulfi", "popsicle", "falooda",
        "sundae", "frozen yogurt",
        
        # Pies & tarts
        "pie", "apple pie", "pumpkin pie", "pecan pie", "tart", "custard tart",
        "fruit tart",
        
        # Puddings & custards
        "pudding", "caramel pudding", "chocolate pudding", "custard", "mousse",
        "souffle", "trifle",
        
        # Confectionery
        "chocolate", "fudge", "candy", "toffee", "marshmallow", "macaron",
        "donut", "doughnut", "waffle", "pancake", "crepe", "churros", "eclair",
        "profiterole"
        ]
        print(desserts)
        for key,value in recipe_list.items():
            if value=='desserts':
                print(key)
    elif choice =='main_courses':
        m_c_k = [
        "rice","bread","curries","noodles pasta","noodles","complete meals","meat dishes","international",
        "biryani", "pulao", "fried rice", "khichdi", "curd rice", "jeera rice",
        "bread", "roti", "chapati", "naan", "paratha", "kulcha", "bhatura", "puri",
        "curries", "dal", "chicken curry", "mutton curry", "paneer butter masala",
        "chole", "rajma", "sambar", "fish curry", "korma", "egg curry",
        "noodles", "chowmein", "ramen", "spaghetti", "pasta", "lasagna",
        "thali", "dal chawal", "idli sambar", "dosa", "uttapam", "pongal",
        "upma", "kadhi chawal", "khichdi",
        "butter chicken", "tandoori chicken", "biryani", "mutton biryani",
        "kebabs (meal sized)", "fish fry with rice",
        "pizza", "burger", "taco", "burrito", "quesadilla", "shawarma",
        "sushi (meal set)", "steak", "casserole"
        ]
        print(main_courses)
        for key,value in recipe_list.items():
            if value=='main_courses':
                print(key)
    elif choice == 'salads':
        salads = [
        # Indian vegetables & fruits
        "cucumber", "tomato", "onion", "carrot", "beetroot", "cabbage",
        "radish", "capsicum", "pomegranate", "apple", "banana", "grapes",
        "orange", "papaya", "moong dal", "chana", "sprouts", "corn",
        "curd", "yogurt", "paneer", "lemon", "coriander", "mint",
        "chat masala", "salt",
    
        # Global vegetables
        "artichoke", "asparagus", "broccoli", "cauliflower", "spinach",
        "lettuce", "kale", "potato", "sweet potato", "okra",
        "eggplant", "zucchini", "bell pepper", "mushroom", "celery",
        "pea", "bean", "radicchio", "parsnip", "turnip",
    
        # Global fruits
        "mango", "pineapple", "strawberry", "blueberry", "blackberry",
        "raspberry", "pear", "peach", "plum", "cherry", "kiwi",
        "watermelon", "melon", "guava", "lychee", "dragon fruit",
        "fig", "dates", "apricot", "passion fruit",
     "kosambari", "kachumber", "raita", "boondi raita", "vegetable raita", "fruit raita",
        "pachadi", "thayir pachadi", "avial salad style",  
        "sprout salad", "moong dal salad", "corn chaat", "fruit chaat",
        "veg chaat", "green salad", "mixed veg salad", "beetroot salad",  
        "paneer salad", "curd salad", "yogurt salad", "onion salad", "cabbage salad", 
     "kachumber", "laccha pyaaz", "raita", "boondi raita", "fruit raita", "paneer raita",
        "pachadi", "thayir pachadi", "kosambari", "kosumalli", "singju",
        "kala chana salad", "sprouted moong salad", "roasted peanut salad",
        "beetroot carrot kosambari", "cabbage & curd mix", "fruit chaat",
        "chickpea salad"
        ]
        print(salads)
        for key,value in recipe_list.items():
            if value=='salads':
                print(key)
    elif choice == 'beverages':
        beverages= [
        # 🧋 North India
        "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
        "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
        "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
        "gur ka sharbat", "ganne ka juice", "sugarcane juice",
        
        # 🍶 West India
        "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
        "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
        "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
        
        # ☕ South India
        "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
        "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
        "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
        "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
        
        # 🍵 East India
        "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
        "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
        "banta soda", "sugarcane juice", "nolen gur milkshake",
        
        # 🍸 Central & Tribal India
        "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
        "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
        
        # 🧃 Pan-India Popular Beverages
        "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
        "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
        "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
        "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
        
        # 🥛 Modern / Street & Fusion Drinks
        "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
        "falooda", "dry fruit shake", "cold cocoa", "rabri falooda", "paan shot",
        
        # 🍹 Festival & Ayurvedic Beveragesbeverages_k = beverages_india = [
        # 🧋 North India
        "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
        "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
        "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
        "gur ka sharbat", "ganne ka juice", "sugarcane juice",
        
        # 🍶 West India
        "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
        "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
        "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
        
        # ☕ South India
        "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
        "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
        "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
        "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
        
        # 🍵 East India
        "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
        "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
        "banta soda", "sugarcane juice", "nolen gur milkshake",
        
        # 🍸 Central & Tribal India
        "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
        "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
        
        # 🧃 Pan-India Popular Beverages
        "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
        "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
        "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
        "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
        
        # 🥛 Modern / Street & Fusion Drinks
        "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
        "thandai", "holi thandai", "kanji", "sattu drink", "panchamrit", "amrit tulsi tea",
        "turmeric milk", "golden milk", "kadha", "herbal decoction", "neem juice"
    
         # North India
        "Lassi, Lah-si",
        "Chhach, Chaach",
        "Sattu Sharbat, Sut-too Shar-bat",
        "Thandai, Thun-dai",
        "Kesar Doodh, Kay-sar Doodh",
        "Noon Chai, Noon Chaai",
        "Kahwa, Kaa-va",
        "Kanji, Kaan-jee",
    
        # West India
        "Solkadhi, Sol-ka-dhi",
        "Aam Panna, Aam Pan-na",
        "Piyush, Pee-yush",
        "Feni, Feh-nee",
        "Kokum Sherbet, Ko-kum Sher-bet",
        "Kesar Kasturi Doodh, Kay-sar Kas-too-ree Doodh",
        "Chaas, Chaas",
    
        # South India
        "Filter Coffee, Filter Kaapi",
        "Jigarthanda, Ji-gar-than-da",
        "Majjige, Maj-ji-gay",
        "Panakam, Paa-na-kam",
        "Tender Coconut Water, Elaneer",
        "Ragi Malt, Raa-gee Malt",
        "Sukku Coffee, Sook-ku Kaapi",
    
        # East India
        "Borhani, Bor-ha-nee",
        "Handia, Han-dee-ya",
        "Mahua, Ma-hoo-aa",
        "Apong, Ah-pong",
        "Xaj Pani, Haaj Pani",
        "Sabja Sharbat, Sub-ja Shar-bat",
    
        # NorthEast Tribal
        "Zutho, Zoo-tho",
        "Thuthse, Thoot-say",
        "Yu, Yoo",
        "Tongba, Tong-baa",
        "Ki Kiad, Kee Kee-ad",
    
        # Pan India Common
        "Chai, Chaai",
        "Masala Chai, Masa-laa Chaai",
        "Nimbu Pani, Nim-boo Paa-nee",
        "Sugarcane Juice, Ganne ka Ras",
        "Badam Milk, Baa-daam Milk",
        "Rose Sharbat, Roaz Shar-bat",
        "Falooda, Fa-loo-daa"
        ]
        print(beverages)
        for key,value in recipe_list.items():
            if value=='beverages':
                print(key)
    elif choice == 'breakfast':
        break_fast = [
        # South India
        "idli", "vada", "pongal", "dosa", "sada dosa", "masala dosa", "uthappam", "puttu", "upma", "appam",
        "palappam", "vellayappam", "idiyappam", "nool puttu", "noolappam", "shavige", "parotta", "pathiri", "pazham pori",
        "masala dosa", "benne dosa", "mysore masala dosa", "set dosa", "rava idli", "akki rotti", "ragi mudde",
        "uppittu", "bisi bele bath", "neer dosa",
        "pesarattu", "mla pesarattu", "upma pesarattu", "dibba rotti", "pulihora", "tamarind rice", "jonna roti", "sajja roti",
    
        # North India
        "paratha", "aloo paratha", "gobi paratha", "paneer paratha", "mooli paratha",
        "poori with aloo sabzi", "chole bhature", "kulcha", "bread pakora",
        "kachori with aloo sabzi", "bedmi poori", "thekua", "jalebi with milk", "puri sabzi",
        "dal baati churma", "mirchi vada", "pyaz kachori", "mawa kachori",
        "litti chokha", "sattu paratha", "chana ghugni with litti",
        "poha jalebi", "samosa", "kachori", "bhutte ka kees",
    
        # West India
        "poha", "kanda poha", "batata poha", "sabudana khichdi", "thalipeeth", "misal pav", "pav", "vada pav",
        "thepla", "fafda jalebi", "khaman dhokla", "handvo", "khakhra", "sev khamani", "patra", "alu vadi",
        "pav with bhaji", "ros omelette", "poi bread with chorizo", "poi bread with vegetable",
    
        # East India
        "luchi with aloor torkari", "radhaballabhi", "chirer polao", "flattened rice", "mughlai paratha",
        "ghugni", "panta bhaat",
        "pakhala bhata", "bara", "chakuli pitha", "enduri pitha", "aloo chop",
        "pitha", "til pitha", "narikol pitha", "chira doi gur", "jolpan",
        "rice with vegetables", "momos", "khasi jadoh", "tungtap",
    
        # Union Territories / Metro Influences
        "french bread", "croissant", "idli", "dosa",
        "cornflakes", "sandwich", "bread butter",
        "parantha with butter and curd",
        "rice", "fish curry", "chapati",
    
        # Common Pan-India Breakfasts
        "idli", "vada", "dosa", "upma", "pongal", "puttu",
        "paratha", "poori sabzi", "kachori sabzi",
        "poha", "chole bhature", "kulcha",
        "bread butter", "bread pakora", "sandwich",
        "tea biscuit", "coffee bun", "milk cornflakes"
        ]
        print(break_fast)
        for key,value in recipe_list.items():
            if value=='break_fast':
                print(key)
    elif choice == 'soups':
        soups_india = [
        # North India
        "Rasam",
        "Sambar",
        "Mulligatawny Soup",
        "Thukpa",
        "Masor Tenga",
        "Macher Jhol",
        "Khar",
        "Dal Shorba",
        "Tomato Soup",
        "Sweet Corn Soup",
        "Vegetable Soup",
        "Chicken Soup",
        "Mutton Soup",
        "Kadhi",
        "Dal Makhani Soup",
        "Sarson Da Saag Soup",
        "Gatte Ki Sabzi Soup",
        "Kadhi Pakora Soup",
        
        # East India
        "Fish Soup",
        "Prawn Soup",
        "Shutki Fish Soup",
        "Dalma",
        "Machha Besara",
        "Shorshe Ilish Soup",
        
        # West India
        "Maharashtrian Spiced Soup",
        "Pithla Bhakri Soup",
        "Sol Kadhi",
        "Handvo Soup",
        "Bajra Khichdi Soup",
        "Methi Thepla Soup",
        
        # South India
        "Paruppu Rasam",
        "Pepper Rasam",
        "Bisi Bele Bath Soup",
        "Ragi Soup",
        "Vegetable Stew",
        "Meen Curry Soup",
        "Dal Bafla Soup",
        "Poha Soup",
        "Sannas Soup",
        "Caldo Verde",
        "Mulligatawny Soup",  # already in North India, keep only once
        "Sattu Sharbat",
        "Litti Chokha Soup",
        
        # NorthEast / Tribal India
        "Thukpa",  # already in North India
        "Paka Lawa",
        "Eromba Soup",
        "Ooti Soup",
        "Jadoh Soup",
        "Dohneiiong Soup",
        "Bamboo Shoot Soup",
        "Vawksa Rep",
        "Smoked Pork Soup",
        "Zutho Soup",
        "Mui Borok",
        "Wahan Macher Jhol",
        "Sohphie Thukpa",
        "Smoked Meat Soup",
        
        # Pan-India / Popular Indo-Chinese / Fusion
        "Hot & Sour Soup",
        "Lemon Coriander Soup",
        "Manchow Soup",
        "Talumein Soup",
        "Clear Vegetable Soup"
        ]
        print(soups_india)
        for key,value in recipe_list.items():
            if value=='soups':
                print(key)
    elif choice == 'side_dishes':
        for key,value in recipe_list.items():
            if value=='side_dishes':
                print(key)
    elif choice == 'snacks':

# %%
f = open('beverages.csv','a+',encoding = 'utf-8')
f.close()

# %%
salads, breakfast,snacks, beverages , main_courses,side_dishes,desserts

# %%
import pygame
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
r = {'err':12,'potato chips':'snacks'}
e = input('pls enter')
for i in r:
    for o in e:
        if i==o:
            print('succeed')
            p =r[e]
            '.csv'.join()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 r = {'err':12,'potato chips':'snacks'}
# ----> 2 r[0]
#
# KeyError: 0

# %%
n=0
while n!=2:
    print('power')
    n=n+1
# Out:
# power
# power

# %%
r = {'err':12,'potato chips':'snacks','mur':'snacks','pur':'snacks'}
t = r.values()
for i in r:
    for i in t:
        if t=='snacks':
# Out:
#   Cell In[60], line 4
#
#     ^
# SyntaxError: incomplete input

# %%
r = {'err':12,'potato chips':'snacks','mur':'snacks','pur':'snacks'}
for key,values in r.items():
    if values == 'snacks':
        print(key)
# Out:
# potato chips
# mur
# pur

# %%
r = {'err':'ff','potato chips':'snacks'}
t = r['err']
if t == 'ff':
    print('success')
# Out:
# success

# %%
r[e]=w
r
# Out:
# {'err': 12, 'potato chips': 'snacks', 'errr': 'fff'}

# %%
def ingredients(self):
    no,recipe_name=recipe_name()
    
    if no==1:
        starter_f=open('starter.csv','a+',encoding='utf-8')
        starters=csv.writer(starter_f)
        
        starters.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains , Lentils,Nuts(seeds), Herbs(Aromatics), Spices(Powders), Sauces(Condiments), Oils(Fats),Preparation Time,Veg/Non-veg'])
        starters.writerow(['','',recipe_name,'','','','','','','','','','','']])
        recipe_list = []
        recipe_list.append(recipe_name)
        prep_time = input('pls enter your preparation time for this dish')
        starters.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg')
        starters.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables, Fruits, Items(Dairy Products & Meat-Seafood & Paclaged Items), Grains, Lentils, Nuts & Seeds, Herbs/Aromatics, Spices/Powders, Sauces/ Condiments, Oils/Fats]').lower()
           
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                starters.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                starters.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                starters.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                starters.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                lentils = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','',lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre== 'over':
                print('thanks for using our code')
                recipe_list = []
                break

    elif no==2:
        salad_f = open('salads.csv','a+',encoding='utf-8')
        salads= csv.writer(salad_f)
        
        salads.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains , Lentils,Nuts(seeds), Herbs(Aromatics), Spices(Powders), Sauces(Condiments), Oils(Fats),Preparation Time,Veg/Non-veg'])
        salads.writerow(['','',recipe_name,'','','','','','','','','','','']])
        
        recipe_list.append(recipe_name)
        prep_time = input('pls enter your preparation time for this dish')
        salads.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg')
        salads.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            ingre = input('pls say what you would like to enter first in this [Vegetables, Fruits, Items(Dairy Products & Meat-Seafood & Paclaged Items), Grains, Lentils, Nuts & Seeds, Herbs/Aromatics, Spices/Powders, Sauces/ Condiments, Oils/Fats]').lower()
            
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                salads.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                salads.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                salads.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                salads.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                starters.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                salads.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==3:
        breakfast_f=open('breakfast.csv','a+',encoding='utf-8')
        breakfast = csv.writer(breakfast_f)
        breakfast.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        breakfast.writerow(['','',recipe_name,'','','','','','','','','','','']])
    
        recipe_list.append(recipe_name)
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        breakfast.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        breakfast.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                breakfast.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                breakfast.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                lentils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','',lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==4:
        snacks_f=open('breakfast.csv','a+',encoding='utf-8')
        snacks = csv.writer(snacks_f)
        snacks.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        snacks.writerow(['','',recipe_name,'','','','','','','','','','','']])
        
        recipe_list.append(recipe_name)
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        snacks.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        breakfast.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                snacks.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                snacks.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each item ')
                items = input('so pls enter your fruits: ')
                snacks.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                snacks.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==5:
        beverages_f=open('breakfast.csv','a+',encoding='utf-8')
        beverages = csv.writer(beverages_f)
        beverages.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        beverages.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        beverages.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                beverages.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                beverages.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                beverages.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                beverages.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==6:
        soups_f=open('breakfast.csv','a+',encoding='utf-8')
        soups = csv.writer(soups_f)
        soups.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        soups.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        soups.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                soups.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                soups.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                soups.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                soups.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                soups.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==7:
        main_courses_f=open('breakfast.csv','a+',encoding='utf-8')
        main_courses = csv.writer(main_courses_f)
        main_courses.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        main_courses.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        main_courses.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                main_courses.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                main_courses.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                main_courses.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==8:
        side_dishes_f=open('breakfast.csv','a+',encoding='utf-8')
        side_dishes = csv.writer(side_dishes_f)
        side_dishes.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        side_dishes.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        side_dishes.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                side_dishes.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='lentils':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                side_dishes.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

    elif no==9:
        desserts_f=open('breakfast.csv','a+',encoding='utf-8')
        desserts = csv.writer(desserts_f)
        desserts.writerow(['Sl-No,Recipe_Name,Vegetables,Fruits,Items(Dairy,Products & Meat-Seafood & Packaged Items),Grains,Lentils,Nuts(seeds),Herbs(Aromatics),Spices(Powders),Sauces(Condiments),Oils(Fats),Preparation Time,Veg/Non-veg'])
        prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
        desserts.writerow(['','','','','','','','','','','','',prep_time,''])
        veg_nveg = input('pls say if your dish is veg or non-veg: ')
        desserts.writerow(['','','','','','','','','','','','','',veg_nveg])
        while True:
            
            ingre = input('pls say what you would like to enter first in this [Vegetables ,Fruits,Items(Dairy Products & Meat-Seafood & Paclaged Items),Grains ,Lentils ,Nuts & Seeds ,Herbs/Aromatics , Spices/Powders , Sauces/ Condiments , Oils/Fats]').lower()
            if ingre == 'vegetables':
                print('pls leave a spacebar after entering each item ')
                vegetab = input('so pls enter your vegetables: ')
                desserts.writerow(['','',vegetab,'','','','','','','','','','',''])
            elif ingre =='fruits':
                print('pls leave a spacebar after entering each time ')
                fruits = input('so pls enter your fruits: ')
                desserts.writerow(['','','',fruits,'','','','','','','','','',''])
            elif ingre =='items':
                print('pls leave a spacebar after entering each time ')
                items = input('so pls enter your fruits: ')
                desserts.writerow(['','','','',items,'','','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                grains = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','',grains,'','','','','','','',''])
            elif ingre =='grains':
                print('pls leave a spacebar after entering each time ')
                Lentils = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','','',Lentils,'','','','','','',''])
            elif ingre =='nuts':
                print('pls leave a spacebar after entering each time ')
                nuts = input('so pls enter your fruits: ')
                desserts.writerow(['','','','','','','',nuts,'','','','','',''])
    
            elif ingre =='herbs':
                print('pls leave a spacebar after entering each time ')
                herbs = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','',herbs,'','','','',''])
    
            elif ingre =='spices':
                print('pls leave a spacebar after entering each time ')
                spices = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','',spices,'','','',''])
    
            elif ingre =='sauces':
                print('pls leave a spacebar after entering each time ')
                sauces = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
            elif ingre =='oils':
                print('pls leave a spacebar after entering each time ')
                oils = input('so pls enter your fruits: ')
                breakfast.writerow(['','','','','','','','','','','',oils,'',''])
            elif ingre == 'over':
                print('thanks for using our code')
                break

# %%
r = 'per'
e = r+'.csv'
# Out:
# per.csv

# %%
i = input('pls enter your').split()
print(i)
for p in i:
    for y in e:
        if p==y:
            norm = []
            norm.append(i)
            pass
            
        else:
            pass
print(norm)
# Out:
# pls enter your apple
# ['apple']
# ['apple pie']
