# %%
class recipe_manager:
    
    z_1=0
    z_2=0
    z_3=0
    z_4=0
    z_5=0
    z_6=0
    z_7=0
    z_8=0
    z_9=0
    recipe_list = {}
    sl_no=0
    
    def __init__(self):
        self.load_data()
        print('Welcome to the recipe manager')
        print('pls store any kind of ingredeint and you dont have to type everything ,so relaxed')
    def save_data(self):
        import json, os
        data = {
            "recipe_list": recipe_manager.recipe_list,
            "sl_no": recipe_manager.sl_no,
            "z_1": recipe_manager.z_1,
            "z_2": recipe_manager.z_2,
            "z_3": recipe_manager.z_3,
            "z_4": recipe_manager.z_4,
            "z_5": recipe_manager.z_5,
            "z_6": recipe_manager.z_6,
            "z_7": recipe_manager.z_7,
            "z_8": recipe_manager.z_8,
            "z_9": recipe_manager.z_9
        }
    
        with open("recipe_data.json", "w", encoding="utf-8") as f:
            json.dump(data, f, indent=4)
    def load_data(self):
        import json, os
        if os.path.exists("recipe_data.json"):
            with open("recipe_data.json", "r", encoding="utf-8") as f:
                data = json.load(f)
                recipe_manager.recipe_list = data.get("recipe_list", {})
                recipe_manager.sl_no = data.get("sl_no", 1)
                recipe_manager.z_1 = data.get("z_1", 0)
                recipe_manager.z_2 = data.get("z_2", 0)
                recipe_manager.z_3 = data.get("z_3", 0)
                recipe_manager.z_4 = data.get("z_4", 0)
                recipe_manager.z_5 = data.get("z_5", 0)
                recipe_manager.z_6 = data.get("z_6", 0)
                recipe_manager.z_7 = data.get("z_7", 0)
                recipe_manager.z_8 = data.get("z_8", 0)
                recipe_manager.z_9 = data.get("z_9", 0)

    
    def recipe_name(self):
        m_c_k = [
            "rice","bread","curries","noodles pasta","noodles","complete meals","meat dishes","international",
            "biryani", "pulao", "fried rice", "khichdi", "curd rice", "jeera rice",
            "bread", "roti", "chapati", "naan", "paratha", "kulcha", "bhatura", "puri",
            "curries", "dal", "chicken curry", "mutton curry", "paneer butter masala",
            "chole", "rajma", "sambar", "fish curry", "korma", "egg curry",
            "noodles", "chowmein", "ramen", "spaghetti", "pasta", "lasagna",
            "thali", "dal chawal", "idli sambar", "dosa", "uttapam", "pongal",
            "upma", "kadhi chawal", "khichdi",
            "butter chicken", "tandoori chicken", "biryani", "mutton biryani",
            "kebabs (meal sized)", "fish fry with rice",
            "pizza", "burger", "taco", "burrito", "quesadilla", "shawarma",
            "sushi (meal set)", "steak", "casserole"
        ]
        d_k = [
            # Indian sweets
            "sweets","sweet",
            "halwa", "kheer", "payasam", "rasgulla", "gulab jamun", "jalebi",
            "laddu", "ladoo", "barfi", "burfi", "peda", "sandesh", "mysore pak",
            "soan papdi", "cham cham", "shrikhand", "malpua", "rabri", "kulfi",
            "phirni", "modak", "gujiya", "sheera", "seviyan", "balushahi",
            
            # Cakes & pastries
            "cake", "cupcake", "brownie", "pastry", "muffin", "cheesecake",
            "sponge cake", "red velvet", "black forest", "fruit cake",
            
            # Frozen desserts
            "ice cream", "gelato", "sorbet", "kulfi", "popsicle", "falooda",
            "sundae", "frozen yogurt",
            
            # Pies & tarts
            "pie", "apple pie", "pumpkin pie", "pecan pie", "tart", "custard tart",
            "fruit tart",
            
            # Puddings & custards
            "pudding", "caramel pudding", "chocolate pudding", "custard", "mousse",
            "souffle", "trifle",
            
            # Confectionery
            "chocolate", "fudge", "candy", "toffee", "marshmallow", "macaron",
            "donut", "doughnut", "waffle", "pancake", "crepe", "churros", "eclair",
            "profiterole"
        ]
        s_k = [
            # Indian vegetables & fruits
            "cucumber", "tomato", "onion", "carrot", "beetroot", "cabbage",
            "radish", "capsicum", "pomegranate", "apple", "banana", "grapes",
            "orange", "papaya", "moong dal", "chana", "sprouts", "corn",
            "curd", "yogurt", "paneer", "lemon", "coriander", "mint",
            "chat masala", "salt",
        
            # Global vegetables
            "artichoke", "asparagus", "broccoli", "cauliflower", "spinach",
            "lettuce", "kale", "potato", "sweet potato", "okra",
            "eggplant", "zucchini", "bell pepper", "mushroom", "celery",
            "pea", "bean", "radicchio", "parsnip", "turnip",
        
            # Global fruits
            "mango", "pineapple", "strawberry", "blueberry", "blackberry",
            "raspberry", "pear", "peach", "plum", "cherry", "kiwi",
            "watermelon", "melon", "guava", "lychee", "dragon fruit",
            "fig", "dates", "apricot", "passion fruit",
         "kosambari", "kachumber", "raita", "boondi raita", "vegetable raita", "fruit raita",
            "pachadi", "thayir pachadi", "avial salad style",  
            "sprout salad", "moong dal salad", "corn chaat", "fruit chaat",
            "veg chaat", "green salad", "mixed veg salad", "beetroot salad",  
            "paneer salad", "curd salad", "yogurt salad", "onion salad", "cabbage salad", 
         "kachumber", "laccha pyaaz", "raita", "boondi raita", "fruit raita", "paneer raita",
            "pachadi", "thayir pachadi", "kosambari", "kosumalli", "singju",
            "kala chana salad", "sprouted moong salad", "roasted peanut salad",
            "beetroot carrot kosambari", "cabbage & curd mix", "fruit chaat",
            "chickpea salad"
        ]  
        st_k = [
            # Indian veg fritters & variations
            "pakora", "pakoda", "bhaji", "bhajji", "bonda", "bajji", "vada",
            "methi pakora", "palak pakora", "mirchi pakora", "mirchi bajji",
            "onion pakora", "onion pakoda", "onion bhaji", "onion bhajji",
        
            # Popular Indian vegetarian starters
            "aloo tikki", "samosa", "paneer tikka", "paneer pakora", "paneer pakoda",
            "paneer 65", "paneer manchurian", "veg cutlet", "veg spring roll",
            "veg manchurian", "momos", "veg momos", "hara bhara kabab",
            "dhokla", "khandvi", "sev puri", "pani puri", "golgappa", "phuchka", "gupchup", "batasha",
            "dahi puri", "bhel puri", "papdi chaat", "chaat", "masala papad",
            "corn tikki", "stuffed paneer", "tandoori mushroom", "baby corn manchurian", "gobi manchurian",
        
            # South Indian snacks (often served as starters)
            "medu vada", "mendu vada", "methu vada", "masala vada", "paruppu vadai",
            "idli fry", "mini idli", "punugulu", "mysore bonda",
        
            # Indian non-veg starters
            "chicken tikka", "tandoori chicken", "chicken lollipop",
            "chicken pakora", "chicken pakoda", "chicken 65", "dragon chicken",
            "pepper chicken", "seekh kabab", "shami kabab", "reshmi kabab",
            "malai tikka", "kalmi kabab", "mutton kabab", "mutton seekh",
            "fish pakora", "fish pakoda", "fish fry", "fish tikka",
            "prawn fry", "tandoori prawns",
            "egg pakora", "egg pakoda", "egg bajji", "egg cutlet", "egg kebab",
            "chicken wings", "buffalo wings",
        
            # International starters
            "french fries", "garlic bread", "bruschetta", "nachos", "stuffed mushrooms",
            "mozzarella sticks", "cheese balls", "jalapeno poppers", "deviled eggs",
            "mini quiche", "dumplings", "spring rolls", "onion rings",
            "tacos (starter size)", "quesadilla (small)",
        ]
        snacks_k = [
        # south india
        "punugulu", "mirchi bajji", "bobbattu", "garelu", "aratikaya bajji",
        "mysore bonda", "maddur vada", "churmuri", "neer dosa", "ragi murukku",
        "vada pav", "pav bhaji", "kanda bhaji", "misal pav", "shankarpali",
        "murukku", "sundal", "vadai", "bajji", "kozhukattai",
        "banana chips", "pazham pori", "unni appam", "achappam", "kozhukatta",
        "sarva pindi", "pesarattu", "osmania biscuit", "mirchi bajji",
    
        # north india
        "samosa", "aloo tikki", "bedmi poori", "kachori", "pani puri", "gol gappa",
        "papdi chaat", "bhel puri", "sev puri", "chole kulche",
        "pyaz kachori", "mirchi vada", "bikaneri bhujia",
        "amritsari fish fry", "bread pakora", "chole bhature",
        "kathi roll", "telebhaja", "shingara", "phuchka", "jhalmuri",
        "pakora", "poha", "dahi vada", "aloo chaat",
    
        # east india
        "litti chokha", "thekua", "ghugni", "muri mixture",
        "chakuli pitha", "gulgula"
        ]
        beverages_k = [
            # 🧋 North India
            "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
            "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
            "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
            "gur ka sharbat", "ganne ka juice", "sugarcane juice",
            
            # 🍶 West India
            "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
            "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
            "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
            
            # ☕ South India
            "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
            "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
            "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
            "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
            
            # 🍵 East India
            "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
            "green tea (assam / darjeeling)", "lemongrass tea", "black tea", "lal cha",
            "banta soda", "sugarcane juice", "nolen gur milkshake",
            
            # 🍸 Central & Tribal India
            "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
            "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
            
            # 🧃 Pan-India Popular Beverages
            "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
            "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
            "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
            "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
            
            # 🥛 Modern / Street & Fusion Drinks
            "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
            "falooda", "dry fruit shake", "cold cocoa", "rabri falooda", "paan shot",
            
            # 🍹 Festival & Ayurvedic Beveragesbeverages_k = beverages_india = [
            # 🧋 North India
            "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
            "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
            "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
            "gur ka sharbat", "ganne ka juice", "sugarcane juice",
            
            # 🍶 West India
            "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
            "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
            "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
            
            # ☕ South India
            "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
            "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
            "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
            "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
            
            # 🍵 East India
            "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
            "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
            "banta soda", "sugarcane juice", "nolen gur milkshake",
            
            # 🍸 Central & Tribal India
            "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
            "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
            
            # 🧃 Pan-India Popular Beverages
            "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
            "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
            "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
            "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
            
            # 🥛 Modern / Street & Fusion Drinks
            "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
            "thandai", "holi thandai", "kanji", "sattu drink", "panchamrit", "amrit tulsi tea",
            "turmeric milk", "golden milk", "kadha", "herbal decoction", "neem juice"
        
             # North India
            "lassi, lah-si",
            "chhach, chaach",
            "sattu sharbat, sut-too shar-bat",
            "thandai, thun-dai",
            "kesar doodh, kay-sar Doodh",
            "noon chai, noon chaai",
            "kahwa, kaa-va",
            "kanji, kaan-jee",
        
            # West India
            "solkadhi, sol-ka-dhi",
            "aam panna, aam pan-na",
            "piyush, pee-yush",
            "feni, feh-nee",
            "kokum sherbet, ko-kum sher-bet",
            "kesar kasturi doodh, kay-sar kas-too-ree doodh",
            "chaas, chaas",
        
            # South India
            "filter coffee, filter kaapi",
            "jigarthanda, ji-gar-than-da",
            "majjige, maj-ji-gay",
            "panakam, paa-na-kam",
            "tender coconut water, elaneer",
            "ragi malt, raa-gee malt",
            "sukku coffee, sook-ku kaapi",
        
            # East India
            "borhani, bor-ha-nee",
            "handia, han-dee-ya",
            "mahua, ma-hoo-aa",
            "apong, ah-pong",
            "xaj pani, haaj pani",
            "sabja sharbat, sub-ja shar-bat",
        
            # NorthEast Tribal
            "zutho, zoo-tho",
            "thuthse, thoot-say",
            "yu, yoo",
            "tongba, tong-baa",
            "ki kiad, kee kee-ad",
        
            # Pan India Common
            "chai, chaai",
            "masala chai, masa-laa chaai",
            "nimbu pani, nim-boo paa-nee",
            "sugarcane juice, ganne ka ras",
            "badam milk, baa-daam milk",
            "rose sharbat, roaz shar-bat",
            "falooda, fa-loo-daa"
        ]
        beverage_pronunciation = {
            # North India
            "lassi": "Lah-si",
            "chhach": "Chaach",
            "sattu sharbat": "Sut-too Shar-bat",
            "thandai": "Thun-dai",
            "kesar doodh": "Kay-sar Doodh",
            "noon chai": "Noon Chaai",
            "kahwa": "Kaa-va",
            "kanji": "Kaan-jee",
            "nimbu pani": "Nim-boo Paa-nee",
            "rose sharbat": "Roaz Shar-bat",
            "badam milk": "Baa-daam Milk",
            "falooda": "Fa-loo-daa",
        
            # West India
            "solkadhi": "Sol-ka-dhi",
            "aam panna": "Aam Pan-na",
            "piyush": "Pee-yush",
            "feni": "Feh-nee",
            "kokum sharbat": "Ko-kum Shar-bet",
            "kesar kasturi doodh": "Kay-sar Kas-too-ree Doodh",
            "chaas": "Chaas",
        
            # South India
            "filter coffee": "Filter Kaapi",
            "jigarthanda": "Ji-gar-than-da",
            "majige": "Maj-ji-gay",
            "panakam": "Paa-na-kam",
            "tender coconut water": "Elaneer",
            "ragi malt": "Raa-gee Malt",
            "sukku coffee": "Sook-ku Kaapi",
        
            # East India
            "borhani": "Bor-ha-nee",
            "handia": "Han-dee-ya",
            "mahua drink": "Ma-hoo-aa",
            "apong": "Ah-pong",
            "xaj pani": "Haaj Pani",
            "sabja sharbat": "sub-ja shar-bat",
        
            # NorthEast Tribal
            "zutho": "Zoo-tho",
            "thuthse": "Thoot-say",
            "yu": "Yoo",
            "tongba": "Tong-baa",
            "ki kiad": "Kee Kee-ad",
        
            # Pan India Common
            "chai": "chaai",
            "masala chai": "masa-laa chaai",
            "sugarcane juice": "ganne ka ras",
        }
        break_fast_k = [
            # South India
            "idli", "vada", "pongal", "dosa", "sada dosa", "masala dosa", "uthappam", "puttu", "upma", "appam",
            "palappam", "vellayappam", "idiyappam", "nool puttu", "noolappam", "shavige", "parotta", "pathiri", "pazham pori",
            "masala dosa", "benne dosa", "mysore masala dosa", "set dosa", "rava idli", "akki rotti", "ragi mudde",
            "uppittu", "bisi bele bath", "neer dosa",
            "pesarattu", "mla pesarattu", "upma pesarattu", "dibba rotti", "pulihora", "tamarind rice", "jonna roti", "sajja roti",
        
            # North India
            "paratha", "aloo paratha", "gobi paratha", "paneer paratha", "mooli paratha",
            "poori with aloo sabzi", "chole bhature", "kulcha", "bread pakora",
            "kachori with aloo sabzi", "bedmi poori", "thekua", "jalebi with milk", "puri sabzi",
            "dal baati churma", "mirchi vada", "pyaz kachori", "mawa kachori",
            "litti chokha", "sattu paratha", "chana ghugni with litti",
            "poha jalebi", "samosa", "kachori", "bhutte ka kees",
        
            # West India
            "poha", "kanda poha", "batata poha", "sabudana khichdi", "thalipeeth", "misal pav", "pav", "vada pav",
            "thepla", "fafda jalebi", "khaman dhokla", "handvo", "khakhra", "sev khamani", "patra", "alu vadi",
            "pav with bhaji", "ros omelette", "poi bread with chorizo", "poi bread with vegetable",
        
            # East India
            "luchi with aloor torkari", "radhaballabhi", "chirer polao", "flattened rice", "mughlai paratha",
            "ghugni", "panta bhaat",
            "pakhala bhata", "bara", "chakuli pitha", "enduri pitha", "aloo chop",
            "pitha", "til pitha", "narikol pitha", "chira doi gur", "jolpan",
            "rice with vegetables", "momos", "khasi jadoh", "tungtap",
        
            # Union Territories / Metro Influences
            "french bread", "croissant", "idli", "dosa",
            "cornflakes", "sandwich", "bread butter",
            "parantha with butter and curd",
            "rice", "fish curry", "chapati",
        
            # Common Pan-India Breakfasts
            "idli", "vada", "dosa", "upma", "pongal", "puttu",
            "paratha", "poori sabzi", "kachori sabzi",
            "poha", "chole bhature", "kulcha",
            "bread butter", "bread pakora", "sandwich",
            "tea biscuit", "coffee bun", "milk cornflakes"
        ]
        snacks_k = [
            # andhra_pradesh
            "punugulu", "garelu", "bobbattu", "pesarattu",
            # telangana
            "osmania biscuit", "sakinalu", "chegodilu",
            # tamil_nadu
            "vadai", "bajji", "murukku", "kozhukattai",
            # kerala
            "unni appam", "achappam", "banana chips", "kozhukatta",
            # karnataka
            "maddur vada", "churmuri", "neer dosa", "mysore bonda",
            # maharashtra
            "vada pav", "pav bhaji", "kanda bhaji", "misal pav", "shankarpali",
            # gujarat
            "dhokla", "khandvi", "thepla", "khakhra", "gathiya",
            # rajasthan
            "pyaz kachori", "mirchi vada", "bikaneri bhujia", "mathri",
            # uttar_pradesh
            "samosa", "aloo tikki", "kachori", "bedmi poori",
            # bihar
            "litti chokha", "thekua", "khaja",
            # west_bengal
            "phuchka", "telebhaja", "jhalmuri", "shingara",
            # odisha
            "chakuli pitha", "chhena poda", "gulgula",
            # madhya_pradesh
            "bhutte ka kees", "sabudana vada", "poha",
            # punjab
            "amritsari fish fry", "chole bhature", "bread pakora",
            # delhi
            "pani puri", "gol gappa", "papdi chaat",
            # assam
            "pitha", "muri mixture",
            # nagaland
            "smoked pork bites", "bamboo shoot fritters",
            # sikkim
            "momo", "thukpa",
            # goa
            "choris pao", "seafood fritters", "bebinca",
            # jammu_kashmir
            "kahwa snacks", "lavang latta", "butter tea snacks",
            # himachal_pradesh
            "siddu",
            # chhattisgarh
            "faraa",
            # jharkhand
            "dhuska",
            # haryana
            "mattha vada",
            # tripura
            "bangui",
            # manipur
            "kelli channa",
            # mizoram
            "kota pitha",
            # union territories
            # lakshadweep
            "seafood fritters",
            # dadra_nagar_haveli_and_daman_diu
            "portuguese breads",
            # ladakh
            "butter tea snacks",
            # puducherry
            "croissant",
            # modern/foreign-influenced
            "burger", "pizza", "french fries", "noodles", "spring rolls",
            "shawarma", "sandwich", "cupcake", "doughnut", "pasta"
                ]
        soups_india = [
            # North India
            "rasam",
            "sambar",
            "mulligatawny soup",
            "thukpa",
            "masor tenga",
            "macher jhol",
            "khar",
            "dal shorba",
            "tomato soup",
            "sweet corn soup",
            "vegetable soup",
            "chicken soup",
            "mutton soup",
            "kadhi",
            "dal makhani soup",
            "sarson da saag soup",
            "gatte ki sabzi soup",
            "kadhi pakora soup",
            
            # East India
            "fish soup",
            "prawn soup",
            "shutki fish soup",
            "dalma",
            "machha besara",
            "shorshe ilish soup",
            
            # West India
            "maharashtrian spiced soup",
            "pithla bhakri soup",
            "sol kadhi",
            "handvo soup",
            "bajra khichdi soup",
            "methi thepla soup",
            
            # South India
            "paruppu rasam",
            "pepper rasam",
            "bisi bele bath soup",
            "ragi soup",
            "vegetable stew",
            "meen curry soup",
            "dal bafla soup",
            "poha soup",
            "sannas soup",
            "caldo verde",
            "mulligatawny soup",  # already in North India, keep only once
            "sattu sharbat",
            "litti chokha soup",
            
            # NorthEast / Tribal India
            "thukpa",  # already in North India
            "paka lawa",
            "eromba soup",
            "ooti soup",
            "jadoh soup",
            "dohneiiong soup",
            "bamboo shoot soup",
            "vawksa rep",
            "smoked pork soup",
            "zutho soup",
            "mui borok",
            "wahan macher jhol",
            "sohphie thukpa",
            "smoked meat soup",
            
            # Pan-India / Popular Indo-Chinese / Fusion
            "hot & sour soup",
            "lemon coriander soup",
            "manchow soup",
            "talumein soup",
            "clear vegetable soup"
        ]
        
    
        
        while True:
            choice = input('if u want to start, pls type yes: ').lower()
            if 'yes' in choice :
                veggies = input('pls enter your recipe [name] ')
                veg = veggies
                
                norm=[]
                print(veg)
                if veg in m_c_k:
                    norm.append(veg)
                    
                    print(f'here are matched words with maincourse{norm}')
                    print(norm) 
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in main_course file ')
                        print('Nice,lets start with your ingredients')
                        return 7,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')

                elif veg in d_k:
                    norm.append(veg)
                    print(f'here are matched words with dessert {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in dessert file ')
                        print('Nice,lets start with your ingredients')
                        return 9,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif veg in s_k:
                    norm.append(veg)
                    print(f'here are matched words with Salad {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in salads file ')
                        print('Nice,lets start with your ingredients')
                        return 2,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif veg in st_k:
                    norm.append(veg)
                    print(f'here are matched words with Starter {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in starter file ')
                        print('Nice,lets start with your ingredients')
                        return 1,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')
    

                elif veg in break_fast_k:
                    norm.append(veg)
                    print(f'here are matched words with break fast {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in break_fast file ')
                        print('Nice,lets start with your ingredients')
                        return 3,veggies
                    else:
            
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif veg in snacks_k:
                    norm.append(veg)
                    print(f'here are matched words with snacks {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in snacks file ')
                        print('Nice,lets start with your ingredients')
                        return 4,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')


                elif veg in beverages_k:
                    norm.append(veg)
                    print(f'here are matched words with beverages {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in beverages file ')
                        print('Nice,lets start with your ingredients')
                        return 5,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')
                        

                elif veg in soups_india:
                    norm.append(veg)
                    print(f'here are matched words with soups {norm}')
                    print(norm)
                    print('if your recipe is in the above list, pls type (yes)')
                    confirmation=input('if confirmed,pls type (yes)').lower()
                    if confirmation=='yes':
                        print('its confirmed, we will store this in soups file ')
                        print('Nice,lets start with your ingredients')
                        return 6,veggies
                    else:
                        print('we didnt find your recipe [name] in our huge list.')
                        print('even though u entered correctly , pls check the spelling of that recipe once,and re-enter')

                else:
                    
                    print('pls type over if you finished writing ')
                    side_dish = input('if it is sidedish pls type (Yes) or (over)').lower()
                    if side_dish == 'Yes':
                        return 8,veggies
                    else:
                        
                        print('so its not sidedish')
                        print('its not present in our list also')
                        print('so pls say if your dishes belong to any of this list [Appetizers/Starters , Salads, Breakfast , Snacks , beverages, Soups, Maincourse,Desserts]')
                        print('if not we are adding it to our side dishes column')
                        print('pls write your choice')
                        choose = input('pls enter can we keep in any list [starter , salad, breakfast , snack , beverage, soup, main_courses,dessert]')
                        if choose == 'starter':
                            return 1,veggies
                        elif choose == 'salad':
                            return 2,veggies
                        elif choose == 'breakfast':
                            return 3,veggies
                        elif choose == 'snacks':
                            return 4,veggies
                        elif choose == 'beverage':
                            return 5,veggies
                        elif choose == 'soup':
                            return 6,veggies
                        elif choose == 'main_courses':
                            return 7,veggies
                        elif choose == 'dessert':
                            return 9,veggies
                
                        elif choose == 'over':
                            print('yes u are quitting now')
                            break
                        
                        else:
                            print('if u want to store  pls type according to given instructions')
            
    def ingredients(self):
        import os
        no,recipe_na=self.recipe_name()
        import csv
        import pandas
        vegetab = ''
        fruits= ''
        items=''
        grains=''
        lentils=''
        nuts=''
        herbs=''
        spices=''
        sauces=''
        oils = ''
        if no==1:
            starter_f=open('starter.csv','a+',encoding='utf-8')
            starters=csv.writer(starter_f)
            while recipe_manager.z_1 != 1:
                starters.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_1 = recipe_manager.z_1 + 1
            st = 'starter'
            recipe_manager.recipe_list[recipe_na]= st
            
            prep_time = input('pls enter your preparation time for this dish')
            veg_nveg = input('pls say if your dish is veg or non-veg')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')

            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
               
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ]')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,dairy,fish,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [chilli(4-spoons) pepper(3-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [tomato(3-spoons) soya(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3-spoons) castor(4-spoons)  ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('starter.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                        
                        
                elif ingre == 'write':
                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no != '':
                            
                            starters.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre== 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
    
        elif no==2:
            
            salad_f = open('salads.csv','a+',encoding='utf-8')
            salads= csv.writer(salad_f)
            while recipe_manager.z_2!=1:
                salads.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_2=recipe_manager.z_2+1
            sa = 'salads'
            recipe_manager.recipe_list[recipe_na]=sa
            prep_time = input('pls enter your preparation time for this dish')
            veg_nveg = input('pls say if your dish is veg or non-veg')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,dairy,fish,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [chilli(3-spoons) pepper(4-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [tomato(3-spoons) soya(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3-spoons) castor(4-spoons)  ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('salads.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':
                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            salads.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
        
        elif no==3:
            
            breakfast_f=open('breakfast.csv','a+',encoding='utf-8')
            breakfast = csv.writer(breakfast_f)
            while recipe_manager.z_3!=1:
                breakfast.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_3=recipe_manager.z_3+1
            br = 'breakfast'
            recipe_manager.recipe_list[recipe_na]=br
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                    breakfast.writerow(['','',vegetab,'','','','','','','','','','',''])
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                    breakfast.writerow(['','','',fruits,'','','','','','','','','',''])
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,fish,dairy,etc]: ')
                    breakfast.writerow(['','','','',items,'','','','','','','','',''])
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                    breakfast.writerow(['','','','','',grains,'','','','','','','',''])
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    lentils = input('so pls enter your lentils: ')
                    breakfast.writerow(['','','','','','',lentils,'','','','','','',''])
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
                    breakfast.writerow(['','','','','','','',nuts,'','','','','',''])
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
                    breakfast.writerow(['','','','','','','','',herbs,'','','','',''])
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [salt(2-spoons) chilli(4-spoons)  ] ')
                    spices = input('so pls enter your spices: ')
                    breakfast.writerow(['','','','','','','','','',spices,'','','',''])
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [tomato(3-spoons) soya(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                    breakfast.writerow(['','','','','','','','','','',sauces,'','',''])
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3-spoons) castor(4-spoons)  ] ')
                    oils = input('so pls enter your oils: ')
                    breakfast.writerow(['','','','','','','','','','','',oils,'',''])
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('breakfast.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':
                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            
                            breakfast.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
    
        elif no==4:
            
            snacks_f=open('snacks.csv','a+',encoding='utf-8')
            snacks = csv.writer(snacks_f)
            while recipe_manager.z_4!=1:
                snacks.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_4=recipe_manager.z_4+1
            sn = 'snacks'
            recipe_manager.recipe_list[recipe_na]=sn
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,dairy,fish,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [pepper(100g) chilli(2-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [soya(2-spoons) or chiili(2-4gm) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(1-spoon) or groundnut(5ml) ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('snacks.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':

                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            snacks.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
            
    
        elif no==5:
            
            beverages_f=open('beverages.csv','a+',encoding='utf-8')
            beverages = csv.writer(beverages_f)
            while recipe_manager.z_5!=1:
                beverages.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_5=recipe_manager.z_5+1
            be='beverages'
            recipe_manager.recipe_list[recipe_na]=be
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,fish,dairy,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [salt(2-spoons) chilli(4-spoons)  ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [tomato(3-spoons) soya(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3-spoons) castor(4-spoons)  ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('beverages.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':

                    print('type (s) if done ')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!= '':
                            beverages.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
    
        elif no==6:
            
            soups_f=open('soups.csv','a+',encoding='utf-8')
            soups = csv.writer(soups_f)
            while recipe_manager.z_6!=1:
                soups.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_6=recipe_manager.z_6+1
            so='soups'
            recipe_manager.recipe_list[recipe_na]=so
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[fish,meat,dairy, etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g) ] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [pepper(3-spoons) salt(4-spoons) } ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [soya(3-spoons) chilli(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3-spoons) castor(4-spoons) ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('soups.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':

                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            soups.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
    
        elif no==7:
            
            main_courses_f=open('main_courses.csv','a+',encoding='utf-8')
            main_courses = csv.writer(main_courses_f)
            while recipe_manager.z_7!=1:
                main_courses.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_7=recipe_manager.z_7+1
            mac='main_courses'
            recipe_manager.recipe_list[recipe_na]=mac
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each ingredient for example [onion(3) potato(4) ] ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ] ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,fish,dairy,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g)] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [pepper(1-spoon) salt(2-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [tomato(3-spoons) chilli(4-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(3) castor(4) ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('main_courses.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':

                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no != '':
                            
                            main_courses.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
        
    
        elif no==8:
            
            side_dishes_f=open('side_dishes.csv','a+',encoding='utf-8')
            side_dishes = csv.writer(side_dishes_f)
            while recipe_manager.z_8!=1:
                side_dishes.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_8=recipe_manager.z_8+1
            sid='side_dishes'
            recipe_manager.recipe_list[recipe_na]=sid
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each item ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ]  ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat,dairy fish,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ]')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g)] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [salt(2-spoons) chilli(4-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [(chilli(2-spoons) soya(4 tea-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each  ingredient for example [(almond(2-spoons) castor(4 tea-spoons) ]')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('side_dishes.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':
                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            
                            side_dishes.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break
    
        elif no==9:
            
            desserts_f=open('desserts.csv','a+',encoding='utf-8')
            desserts = csv.writer(desserts_f)
            
            while recipe_manager.z_9!=1:
                desserts.writerow(['Sl-No','Recipe_Name','Vegetables','Fruits','Items(Dairy,Products & Meat-Seafood & Packaged Items)','Grains' , 'Lentils','Nuts(seeds)', 'Herbs(Aromatics)', 'Spices(Powders)', 'Sauces(Condiments)', 'Oils(Fats)','Preparation Time','Veg/Non-veg'])
                recipe_manager.z_9=recipe_manager.z_9+1
            de = 'desserts'
            recipe_manager.recipe_list[recipe_na]=de
            prep_time = input('pls enter your preparation time for this dish for example - (30 min) : ')
            veg_nveg = input('pls say if your dish is veg or non-veg: ')
            print('so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category')
            while True:
                
                ingre = input('pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)]').lower()
                if ingre == '1':
                    print('pls leave a spacebar after entering each item ')
                    vegetab = input('so pls enter your vegetables: ')
                elif ingre =='2':
                    print('pls leave a spacebar after entering each ingredient for example [banana(3) apple(4) ]  ')
                    fruits = input('so pls enter your fruits: ')
                elif ingre =='3':
                    print('pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ] ')
                    items = input('so pls enter your items[meat, dairy,etc]: ')
                elif ingre =='4':
                    print('pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ] ')
                    grains = input('so pls enter your grains: ')
                elif ingre =='5':
                    print('pls leave a spacebar after entering each ingredient for example [black(30g) red(40g) ] ')
                    Lentils = input('so pls enter your lentils: ')
                elif ingre =='6':
                    print('pls leave a spacebar after entering each ingredient for example [almonds(300g) cashew(100g)] ')
                    nuts = input('so pls enter your nuts: ')
        
                elif ingre =='7':
                    print('pls leave a spacebar after entering each ingredient for example [basil(3-bunch) coriander(4-bunch) ] ')
                    herbs = input('so pls enter your herbs: ')
        
                elif ingre =='8':
                    print('pls leave a spacebar after entering each ingredient for example [salt(2-spoons) chilli(4-spoons) ] ')
                    spices = input('so pls enter your spices: ')
        
                elif ingre =='9':
                    print('pls leave a spacebar after entering each ingredient for example [chilli(4-spoons) soya(3-spoons) ] ')
                    sauces = input('so pls enter your sauces: ')
                elif ingre =='10':
                    print('pls leave a spacebar after entering each ingredient for example [almond(2-spoons) castor(2-spoons) ] ')
                    oils = input('so pls enter your oils: ')
                elif ingre == 'print':
                    print(f'vegetables : {vegetab if vegetab else "-"}')
                    print(f'fruits : {fruits if fruits else "-"}')
                    print(f'items : {items if items else "-" }')
                    print(f'grains : {grains if grains else "-"}')
                    print(f'lentils : {lentils if lentils else "-"}')
                    print(f'nuts : {nuts if nuts else "-"}')
                    print(f'herbs : {herbs if herbs else "-"}')
                    print(f'spices : {spices if spices else "-"}')
                    print(f'sauces : {sauces if sauces else "-"}')
                    print(f'oils : {oils if oils else "-"}')
                    print('if accepted type (s) OR (here)')
                    edit = input('do you want to edit here only or directly in csv (we will auto run your csv file of this category) :').lower()
                    if edit == 's':
                        os.startfile('desserts.csv')
                        break
                    else:
                        print('pls type (write) to finally write into csv file')
                elif ingre == 'write':
                    print('type (s) if done')
                    done= input('did you correct or edit all your mistakes').lower()
                    if done == 's':
                        if no!='':
                            
                            desserts.writerow([recipe_manager.sl_no,recipe_na,vegetab,fruits,items,grains,lentils,nuts,herbs,spices,sauces,oils,prep_time,veg_nveg])
                            recipe_manager.sl_no += 1
                        else:
                            print('pls correct all your mistakes')
                    else:
                        print('pls correct all your mistakes')
                elif ingre == 'over':
                    print('thanks for using our code')
                    self.save_data()
                    break            
    def search(self,recipe_name):
        import pandas as p
        category = recipe_manager.recipe_list[recipe_name]
        print(f' this recipe belongs to {category}')
        if category == 'starter':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\starter.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)
        elif category == 'salads':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\salads.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row) 
    
        elif category == 'breakfast':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\breakfast.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row) 
    
            
        elif category == 'snacks':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\snacks.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)  
    
        elif category == 'snacks':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\snacks.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)
    
        elif category == 'beverages':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\beverages.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)
    
        elif category == 'main_courses':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\main_courses.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)
    
        elif category == 'side_dishes':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\side_dishes.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)
    
        elif category == 'desserts':
            data = p.read_csv("C:\\Users\\sampar\\python projects\\desserts.csv")
            search_col = 'Recipe_Name'
            search_recipe = recipe_name
            for idx,row in data.iterrows():
                if row[search_col]==search_recipe:
                    print(idx)
                    print(row)

    def spelling(self,recipe_name):
        choice = input('pls input which category you want to display for category')
        if choice == 'starter':
            starters= [ # Indian veg fritters & variations
            "pakora", "pakoda", "bhaji", "bhajji", "bonda", "bajji", "vada", "vadai",
            "methi pakora", "palak pakora", "mirchi pakora", "mirchi bajji",
            "onion pakora", "onion pakoda", "onion bhaji", "onion bhajji",
        
            # Popular Indian vegetarian starters
            "aloo tikki", "samosa", "paneer tikka", "paneer pakora", "paneer pakoda",
            "paneer 65", "paneer manchurian", "veg cutlet", "veg spring roll",
            "veg manchurian", "momos", "veg momos", "hara bhara kabab",
            "dhokla", "khandvi", "sev puri", "pani puri", "golgappa", "phuchka", "gupchup", "batasha",
            "dahi puri", "bhel puri", "papdi chaat", "chaat", "masala papad",
            "corn tikki", "stuffed paneer", "tandoori mushroom", "baby corn manchurian", "gobi manchurian",
        
            # South Indian snacks (often served as starters)
            "medu vada", "mendu vada", "methu vada", "masala vada", "paruppu vadai",
            "idli fry", "mini idli", "punugulu", "mysore bonda",
        
            # Indian non-veg starters
            "chicken tikka", "tandoori chicken", "chicken lollipop",
            "chicken pakora", "chicken pakoda", "chicken 65", "dragon chicken",
            "pepper chicken", "seekh kabab", "shami kabab", "reshmi kabab",
            "malai tikka", "kalmi kabab", "mutton kabab", "mutton seekh",
            "fish pakora", "fish pakoda", "fish fry", "fish tikka",
            "prawn fry", "tandoori prawns",
            "egg pakora", "egg pakoda", "egg bajji", "egg cutlet", "egg kebab",
            "chicken wings", "buffalo wings",
        
            # International starters
            "french fries", "garlic bread", "bruschetta", "nachos", "stuffed mushrooms",
            "mozzarella sticks", "cheese balls", "jalapeno poppers", "deviled eggs",
            "mini quiche", "dumplings", "spring rolls", "onion rings",
            "tacos (starter size)", "quesadilla (small)",   
            ]
            
            print(starter)
            for key,value in recipe_manager.recipe_list.items():
                if value=='starter':
                    print(key)
        elif choice == 'desserts':
            desserts = [
            # Indian sweets
            "sweets","sweet",
            "halwa", "kheer", "payasam", "rasgulla", "gulab jamun", "jalebi",
            "laddu", "ladoo", "barfi", "burfi", "peda", "sandesh", "mysore pak",
            "soan papdi", "cham cham", "shrikhand", "malpua", "rabri", "kulfi",
            "phirni", "modak", "gujiya", "sheera", "seviyan", "balushahi",
            
            # Cakes & pastries
            "cake", "cupcake", "brownie", "pastry", "muffin", "cheesecake",
            "sponge cake", "red velvet", "black forest", "fruit cake",
            
            # Frozen desserts
            "ice cream", "gelato", "sorbet", "kulfi", "popsicle", "falooda",
            "sundae", "frozen yogurt",
            
            # Pies & tarts
            "pie", "apple pie", "pumpkin pie", "pecan pie", "tart", "custard tart",
            "fruit tart",
            
            # Puddings & custards
            "pudding", "caramel pudding", "chocolate pudding", "custard", "mousse",
            "souffle", "trifle",
            
            # Confectionery
            "chocolate", "fudge", "candy", "toffee", "marshmallow", "macaron",
            "donut", "doughnut", "waffle", "pancake", "crepe", "churros", "eclair",
            "profiterole"
            ]
            print(desserts)
            for key,value in recipe_manager.recipe_list.items():
                if value=='desserts':
                    print(key)
        elif choice =='main_courses':
            m_c_k = [
            "rice","bread","curries","noodles pasta","noodles","complete meals","meat dishes","international",
            "biryani", "pulao", "fried rice", "khichdi", "curd rice", "jeera rice",
            "bread", "roti", "chapati", "naan", "paratha", "kulcha", "bhatura", "puri",
            "curries", "dal", "chicken curry", "mutton curry", "paneer butter masala",
            "chole", "rajma", "sambar", "fish curry", "korma", "egg curry",
            "noodles", "chowmein", "ramen", "spaghetti", "pasta", "lasagna",
            "thali", "dal chawal", "idli sambar", "dosa", "uttapam", "pongal",
            "upma", "kadhi chawal", "khichdi",
            "butter chicken", "tandoori chicken", "biryani", "mutton biryani",
            "kebabs (meal sized)", "fish fry with rice",
            "pizza", "burger", "taco", "burrito", "quesadilla", "shawarma",
            "sushi (meal set)", "steak", "casserole"
            ]
            print(main_courses)
            for key,value in recipe_manager.recipe_list.items():
                if value=='main_courses':
                    print(key)
        elif choice == 'salads':
            salads = [
            # Indian vegetables & fruits
            "cucumber", "tomato", "onion", "carrot", "beetroot", "cabbage",
            "radish", "capsicum", "pomegranate", "apple", "banana", "grapes",
            "orange", "papaya", "moong dal", "chana", "sprouts", "corn",
            "curd", "yogurt", "paneer", "lemon", "coriander", "mint",
            "chat masala", "salt",
        
            # Global vegetables
            "artichoke", "asparagus", "broccoli", "cauliflower", "spinach",
            "lettuce", "kale", "potato", "sweet potato", "okra",
            "eggplant", "zucchini", "bell pepper", "mushroom", "celery",
            "pea", "bean", "radicchio", "parsnip", "turnip",
        
            # Global fruits
            "mango", "pineapple", "strawberry", "blueberry", "blackberry",
            "raspberry", "pear", "peach", "plum", "cherry", "kiwi",
            "watermelon", "melon", "guava", "lychee", "dragon fruit",
            "fig", "dates", "apricot", "passion fruit",
         "kosambari", "kachumber", "raita", "boondi raita", "vegetable raita", "fruit raita",
            "pachadi", "thayir pachadi", "avial salad style",  
            "sprout salad", "moong dal salad", "corn chaat", "fruit chaat",
            "veg chaat", "green salad", "mixed veg salad", "beetroot salad",  
            "paneer salad", "curd salad", "yogurt salad", "onion salad", "cabbage salad", 
         "kachumber", "laccha pyaaz", "raita", "boondi raita", "fruit raita", "paneer raita",
            "pachadi", "thayir pachadi", "kosambari", "kosumalli", "singju",
            "kala chana salad", "sprouted moong salad", "roasted peanut salad",
            "beetroot carrot kosambari", "cabbage & curd mix", "fruit chaat",
            "chickpea salad"
            ]
            print(salads)
            for key,value in recipe_manager.recipe_list.items():
                if value=='salads':
                    print(key)
        elif choice == 'beverages':
            beverages= [
            # 🧋 North India
            "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
            "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
            "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
            "gur ka sharbat", "ganne ka juice", "sugarcane juice",
            
            # 🍶 West India
            "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
            "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
            "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
            
            # ☕ South India
            "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
            "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
            "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
            "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
            
            # 🍵 East India
            "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
            "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
            "banta soda", "sugarcane juice", "nolen gur milkshake",
            
            # 🍸 Central & Tribal India
            "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
            "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
            
            # 🧃 Pan-India Popular Beverages
            "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
            "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
            "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
            "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
            
            # 🥛 Modern / Street & Fusion Drinks
            "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
            "falooda", "dry fruit shake", "cold cocoa", "rabri falooda", "paan shot",
            
            # 🍹 Festival & Ayurvedic Beveragesbeverages_k = beverages_india = [
            # 🧋 North India
            "lassi", "sweet lassi", "salt lassi", "mango lassi", "chaas", "jaljeera", "rooh afza",
            "thandai", "kesaria milk", "badam milk", "noon chai", "kahwa", "rabri milk", "sattu sharbat",
            "nimbu pani", "aam panna", "bel sharbat", "rose sharbat", "imli sharbat", "carrot kanji",
            "gur ka sharbat", "ganne ka juice", "sugarcane juice",
            
            # 🍶 West India
            "solkadhi", "kokum sharbat", "chhaas", "amras", "feni", "neera", "toddy", "panha",
            "rose milk", "aamras milkshake", "falooda", "mango milkshake", "sitaphal milkshake",
            "kharwas milk drink", "kokum soda", "coconut water", "buttermilk soda",
            
            # ☕ South India
            "filter coffee", "degree coffee", "sukku coffee", "rasam drink", "nannari sharbat",
            "elaneer payasam", "pazham milk", "jigarthanda", "kulukki sarbath", "panakam",
            "buttermilk (majige / majjiga / mor)", "kokum drink", "tender coconut water",
            "herbal kashayam", "sol kadhi", "palm juice", "karupatti coffee",
            
            # 🍵 East India
            "borhani", "sattu pani", "rice beer (handia)", "mahua drink", "apong", "zutho", "haozu",
            "green tea (Assam / Darjeeling)", "lemongrass tea", "black tea", "lal cha",
            "banta soda", "sugarcane juice", "nolen gur milkshake",
            
            # 🍸 Central & Tribal India
            "mahua liquor", "handia", "salfi", "tadi", "date palm juice", "tendu sherbet",
            "bael juice", "tamarind sharbat", "herbal tonics", "palm toddy",
            
            # 🧃 Pan-India Popular Beverages
            "masala chai", "ginger tea", "lemon tea", "green tea", "milk tea",
            "cold coffee", "iced coffee", "cold brew", "banana shake", "chocolate shake",
            "rose milk", "cold badam milk", "kesariya milk", "horlicks milk", "bournvita milk",
            "jaljeera soda", "mint lemonade", "orange juice", "mango juice", "pineapple juice",
            
            # 🥛 Modern / Street & Fusion Drinks
            "bubble tea", "kulfi shake", "oreo shake", "kitkat shake", "strawberry milkshake",
            "thandai", "holi thandai", "kanji", "sattu drink", "panchamrit", "amrit tulsi tea",
            "turmeric milk", "golden milk", "kadha", "herbal decoction", "neem juice"
        
             # North India
            "Lassi, Lah-si",
            "Chhach, Chaach",
            "Sattu Sharbat, Sut-too Shar-bat",
            "Thandai, Thun-dai",
            "Kesar Doodh, Kay-sar Doodh",
            "Noon Chai, Noon Chaai",
            "Kahwa, Kaa-va",
            "Kanji, Kaan-jee",
        
            # West India
            "Solkadhi, Sol-ka-dhi",
            "Aam Panna, Aam Pan-na",
            "Piyush, Pee-yush",
            "Feni, Feh-nee",
            "Kokum Sherbet, Ko-kum Sher-bet",
            "Kesar Kasturi Doodh, Kay-sar Kas-too-ree Doodh",
            "Chaas, Chaas",
        
            # South India
            "Filter Coffee, Filter Kaapi",
            "Jigarthanda, Ji-gar-than-da",
            "Majjige, Maj-ji-gay",
            "Panakam, Paa-na-kam",
            "Tender Coconut Water, Elaneer",
            "Ragi Malt, Raa-gee Malt",
            "Sukku Coffee, Sook-ku Kaapi",
        
            # East India
            "Borhani, Bor-ha-nee",
            "Handia, Han-dee-ya",
            "Mahua, Ma-hoo-aa",
            "Apong, Ah-pong",
            "Xaj Pani, Haaj Pani",
            "Sabja Sharbat, Sub-ja Shar-bat",
        
            # NorthEast Tribal
            "Zutho, Zoo-tho",
            "Thuthse, Thoot-say",
            "Yu, Yoo",
            "Tongba, Tong-baa",
            "Ki Kiad, Kee Kee-ad",
        
            # Pan India Common
            "Chai, Chaai",
            "Masala Chai, Masa-laa Chaai",
            "Nimbu Pani, Nim-boo Paa-nee",
            "Sugarcane Juice, Ganne ka Ras",
            "Badam Milk, Baa-daam Milk",
            "Rose Sharbat, Roaz Shar-bat",
            "Falooda, Fa-loo-daa"
            ]
            print(beverages)
            for key,value in recipe_manager.recipe_list.items():
                if value=='beverages':
                    print(key)
        elif choice == 'breakfast':
            break_fast = [
            # South India
            "idli", "vada", "pongal", "dosa", "sada dosa", "masala dosa", "uthappam", "puttu", "upma", "appam",
            "palappam", "vellayappam", "idiyappam", "nool puttu", "noolappam", "shavige", "parotta", "pathiri", "pazham pori",
            "masala dosa", "benne dosa", "mysore masala dosa", "set dosa", "rava idli", "akki rotti", "ragi mudde",
            "uppittu", "bisi bele bath", "neer dosa",
            "pesarattu", "mla pesarattu", "upma pesarattu", "dibba rotti", "pulihora", "tamarind rice", "jonna roti", "sajja roti",
        
            # North India
            "paratha", "aloo paratha", "gobi paratha", "paneer paratha", "mooli paratha",
            "poori with aloo sabzi", "chole bhature", "kulcha", "bread pakora",
            "kachori with aloo sabzi", "bedmi poori", "thekua", "jalebi with milk", "puri sabzi",
            "dal baati churma", "mirchi vada", "pyaz kachori", "mawa kachori",
            "litti chokha", "sattu paratha", "chana ghugni with litti",
            "poha jalebi", "samosa", "kachori", "bhutte ka kees",
        
            # West India
            "poha", "kanda poha", "batata poha", "sabudana khichdi", "thalipeeth", "misal pav", "pav", "vada pav",
            "thepla", "fafda jalebi", "khaman dhokla", "handvo", "khakhra", "sev khamani", "patra", "alu vadi",
            "pav with bhaji", "ros omelette", "poi bread with chorizo", "poi bread with vegetable",
        
            # East India
            "luchi with aloor torkari", "radhaballabhi", "chirer polao", "flattened rice", "mughlai paratha",
            "ghugni", "panta bhaat",
            "pakhala bhata", "bara", "chakuli pitha", "enduri pitha", "aloo chop",
            "pitha", "til pitha", "narikol pitha", "chira doi gur", "jolpan",
            "rice with vegetables", "momos", "khasi jadoh", "tungtap",
        
            # Union Territories / Metro Influences
            "french bread", "croissant", "idli", "dosa",
            "cornflakes", "sandwich", "bread butter",
            "parantha with butter and curd",
            "rice", "fish curry", "chapati",
        
            # Common Pan-India Breakfasts
            "idli", "vada", "dosa", "upma", "pongal", "puttu",
            "paratha", "poori sabzi", "kachori sabzi",
            "poha", "chole bhature", "kulcha",
            "bread butter", "bread pakora", "sandwich",
            "tea biscuit", "coffee bun", "milk cornflakes"
            ]
            print(break_fast)
            for key,value in recipe_manager.recipe_list.items():
                if value=='break_fast':
                    print(key)
        elif choice == 'soups':
            soups_india = [
            # North India
            "Rasam",
            "Sambar",
            "Mulligatawny Soup",
            "Thukpa",
            "Masor Tenga",
            "Macher Jhol",
            "Khar",
            "Dal Shorba",
            "Tomato Soup",
            "Sweet Corn Soup",
            "Vegetable Soup",
            "Chicken Soup",
            "Mutton Soup",
            "Kadhi",
            "Dal Makhani Soup",
            "Sarson Da Saag Soup",
            "Gatte Ki Sabzi Soup",
            "Kadhi Pakora Soup",
            
            # East India
            "Fish Soup",
            "Prawn Soup",
            "Shutki Fish Soup",
            "Dalma",
            "Machha Besara",
            "Shorshe Ilish Soup",
            
            # West India
            "Maharashtrian Spiced Soup",
            "Pithla Bhakri Soup",
            "Sol Kadhi",
            "Handvo Soup",
            "Bajra Khichdi Soup",
            "Methi Thepla Soup",
            
            # South India
            "Paruppu Rasam",
            "Pepper Rasam",
            "Bisi Bele Bath Soup",
            "Ragi Soup",
            "Vegetable Stew",
            "Meen Curry Soup",
            "Dal Bafla Soup",
            "Poha Soup",
            "Sannas Soup",
            "Caldo Verde",
            "Mulligatawny Soup",  # already in North India, keep only once
            "Sattu Sharbat",
            "Litti Chokha Soup",
            
            # NorthEast / Tribal India
            "Thukpa",  # already in North India
            "Paka Lawa",
            "Eromba Soup",
            "Ooti Soup",
            "Jadoh Soup",
            "Dohneiiong Soup",
            "Bamboo Shoot Soup",
            "Vawksa Rep",
            "Smoked Pork Soup",
            "Zutho Soup",
            "Mui Borok",
            "Wahan Macher Jhol",
            "Sohphie Thukpa",
            "Smoked Meat Soup",
            
            # Pan-India / Popular Indo-Chinese / Fusion
            "Hot & Sour Soup",
            "Lemon Coriander Soup",
            "Manchow Soup",
            "Talumein Soup",
            "Clear Vegetable Soup"
            ]
            print(soups_india)
            for key,value in recipe_manager.recipe_list.items():
                if value=='soups':
                    print(key)
        elif choice == 'side_dishes':
            for key,value in recipe_manager.recipe_list.items():
                if value=='side_dishes':
                    print(key)
        elif choice == 'snacks':
            snacks = [
            # andhra_pradesh
            "punugulu", "garelu", "bobbattu", "pesarattu",
            # telangana
            "osmania biscuit", "sakinalu", "chegodilu",
            # tamil_nadu
            "vadai", "bajji", "murukku", "kozhukattai",
            # kerala
            "unni appam", "achappam", "banana chips", "kozhukatta",
            # karnataka
            "maddur vada", "churmuri", "neer dosa", "mysore bonda",
            # maharashtra
            "vada pav", "pav bhaji", "kanda bhaji", "misal pav", "shankarpali",
            # gujarat
            "dhokla", "khandvi", "thepla", "khakhra", "gathiya",
            # rajasthan
            "pyaz kachori", "mirchi vada", "bikaneri bhujia", "mathri",
            # uttar_pradesh
            "samosa", "aloo tikki", "kachori", "bedmi poori",
            # bihar
            "litti chokha", "thekua", "khaja",
            # west_bengal
            "phuchka", "telebhaja", "jhalmuri", "shingara",
            # odisha
            "chakuli pitha", "chhena poda", "gulgula",
            # madhya_pradesh
            "bhutte ka kees", "sabudana vada", "poha",
            # punjab
            "amritsari fish fry", "chole bhature", "bread pakora",
            # delhi
            "pani puri", "gol gappa", "papdi chaat",
            # assam
            "pitha", "muri mixture",
            # nagaland
            "smoked pork bites", "bamboo shoot fritters",
            # sikkim
            "momo", "thukpa",
            # goa
            "choris pao", "seafood fritters", "bebinca",
            # jammu_kashmir
            "kahwa snacks", "lavang latta", "butter tea snacks",
            # himachal_pradesh
            "siddu",
            # chhattisgarh
            "faraa",
            # jharkhand
            "dhuska",
            # haryana
            "mattha vada",
            # tripura
            "bangui",
            # manipur
            "kelli channa",
            # mizoram
            "kota pitha",
            # union territories
            # lakshadweep
            "seafood fritters",
            # dadra_nagar_haveli_and_daman_diu
            "portuguese breads",
            # ladakh
            "butter tea snacks",
            # puducherry
            "croissant",
            # modern/foreign-influenced
            "burger", "pizza", "french fries", "noodles", "spring rolls",
            "shawarma", "sandwich", "cupcake", "doughnut", "pasta"
                ]
            print(snacks)
            for key,value in recipe_manager.recipe_list.items():
                if value=='snacks':
                    print(key)

# %%
wood = recipe_manager()
# Out:
# Welcome to the recipe manager
# pls store any kind of ingredeint and you dont have to type everything ,so relaxed

# %%
wood.ingredients()
# Out:
# if u want to start, pls type yes:  yes
# pls enter your recipe [name]  kota pitha
# kota pitha
# here are matched words with snacks ['kota pitha']
# ['kota pitha']
# if your recipe is in the above list, pls type (yes)
# if confirmed,pls type (yes) yes
# its confirmed, we will store this in snacks file
# Nice,lets start with your ingredients
# pls enter your preparation time for this dish for example - (30 min) :  40-min
# pls say if your dish is veg or non-veg:  veg
# so pls print [vegetable: 1 , Fruits: 2 , items : 3, grains : 4, lentils : 5, nuts : 6 ,herbs : 7 , spices : 8 , sauces : 9 , oils : 10] to store ingredeint accor to the category
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] 4
# pls leave a spacebar after entering each ingredient for example [quinoa(100g) barley(400g) ]
# so pls enter your grains:  kodo_rice_flour
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] 3
# pls leave a spacebar after entering each ingredient for example [meat(1/2kg) milk(4 glasses) ]
# so pls enter your items[meat,dairy,fish,etc]:  jaggery
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] 10
# pls leave a spacebar after entering each ingredient for example [almond(1-spoon) or groundnut(5ml) ]
# so pls enter your oils:  oil/ghee
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] print
# vegetables : -
# fruits : -
# items : jaggery
# grains : kodo_rice_flour
# lentils : -
# nuts : -
# herbs : -
# spices : -
# sauces : -
# oils : oil/ghee
# if accepted type (s) OR (here)
# do you want to edit here only or directly in csv (we will auto run your csv file of this category) : here
# pls type (write) to finally write into csv file
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] print
# vegetables : -
# fruits : -
# items : jaggery
# grains : kodo_rice_flour
# lentils : -
# nuts : -
# herbs : -
# spices : -
# sauces : -
# oils : oil/ghee
# if accepted type (s) OR (here)
# do you want to edit here only or directly in csv (we will auto run your csv file of this category) : here
# pls type (write) to finally write into csv file
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] write
# type (s) if done
# did you correct or edit all your mistakes s
# pls say what you would like to enter first in this [Vegetables(1) ,Fruits(2) ,Items(Dairy Products & Meat-Seafood & Paclaged Items)(3) ,Grains(4) ,Lentils(5) ,Nuts & Seeds(6) ,Herbs/Aromatics(7) , Spices/Powders(8) , Sauces/ Condiments(9) , Oils/Fats(10)] over
# thanks for using our code

# %%
wood.search('kota pitha')
# Out:
#  this recipe belongs to snacks
# 1
# Sl-No                                                                  0
# Recipe_Name                                                   kota pitha
# Vegetables                                                           NaN
# Fruits                                                               NaN
# Items(Dairy,Products & Meat-Seafood & Packaged Items)            jaggery
# Grains                                                   kodo_rice_flour
# Lentils                                                              NaN
# Nuts(seeds)                                                          NaN
# Herbs(Aromatics)                                                     NaN
# Spices(Powders)                                                      NaN
# Sauces(Condiments)                                                   NaN
# Oils(Fats)                                                      oil/ghee
# Preparation Time                                                  40-min
# Veg/Non-veg                                                          veg
# Name: 1, dtype: object

# %%
wood.spelling('kota pitha')
# Out:
# pls input which category you want to display for category snacks
# ['punugulu', 'garelu', 'bobbattu', 'pesarattu', 'osmania biscuit', 'sakinalu', 'chegodilu', 'vadai', 'bajji', 'murukku', 'kozhukattai', 'unni appam', 'achappam', 'banana chips', 'kozhukatta', 'maddur vada', 'churmuri', 'neer dosa', 'mysore bonda', 'vada pav', 'pav bhaji', 'kanda bhaji', 'misal pav', 'shankarpali', 'dhokla', 'khandvi', 'thepla', 'khakhra', 'gathiya', 'pyaz kachori', 'mirchi vada', 'bikaneri bhujia', 'mathri', 'samosa', 'aloo tikki', 'kachori', 'bedmi poori', 'litti chokha', 'thekua', 'khaja', 'phuchka', 'telebhaja', 'jhalmuri', 'shingara', 'chakuli pitha', 'chhena poda', 'gulgula', 'bhutte ka kees', 'sabudana vada', 'poha', 'amritsari fish fry', 'chole bhature', 'bread pakora', 'pani puri', 'gol gappa', 'papdi chaat', 'pitha', 'muri mixture', 'smoked pork bites', 'bamboo shoot fritters', 'momo', 'thukpa', 'choris pao', 'seafood fritters', 'bebinca', 'kahwa snacks', 'lavang latta', 'butter tea snacks', 'siddu', 'faraa', 'dhuska', 'mattha vada', 'bangui', 'kelli channa', 'kota pitha', 'seafood fritters', 'portuguese breads', 'butter tea snacks', 'croissant', 'burger', 'pizza', 'french fries', 'noodles', 'spring rolls', 'shawarma', 'sandwich', 'cupcake', 'doughnut', 'pasta']
# kota pitha

# %%
f = open('snacks','a+',encoding='utf-8')
f.c

# %%
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
import pygame
import sys
import time

# Initialize pygame
pygame.init()

# Create a window (width=500, height=300)
screen = pygame.display.set_mode((500, 300))
pygame.display.set_caption("Pygame Test Window")

# Fill background color (light gray)
screen.fill((200, 200, 200))
pygame.display.flip()  # Update the screen

# Wait for 3 seconds or until user closes window
start_time = time.time()
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    if time.time() - start_time > 3:
        running = False

pygame.quit()
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import time
import random

# Initialize pygame
pygame.init()

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
red = (213, 50, 80)
green = (0, 255, 0)
blue = (50, 153, 213)

# Screen dimensions
width = 600
height = 400

# Create game window
dis = pygame.display.set_mode((width, height))
pygame.display.set_caption('Snake Game by Athish')

# Clock & font
clock = pygame.time.Clock()
snake_block = 10
snake_speed = 15
font_style = pygame.font.SysFont("bahnschrift", 25)
score_font = pygame.font.SysFont("comicsansms", 25)


def your_score(score):
    value = score_font.render("Score: " + str(score), True, black)
    dis.blit(value, [10, 10])


def our_snake(snake_block, snake_list):
    for x in snake_list:
        pygame.draw.rect(dis, black, [x[0], x[1], snake_block, snake_block])


def message(msg, color):
    mesg = font_style.render(msg, True, color)
    dis.blit(mesg, [width / 6, height / 3])


def gameLoop():
    game_over = False
    game_close = False

    x1 = width / 2
    y1 = height / 2

    x1_change = 0
    y1_change = 0

    snake_List = []
    Length_of_snake = 1

    foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
    foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0

    while not game_over:

        while game_close:
            dis.fill(blue)
            message("You Lost! Press C-Play Again or Q-Quit", red)
            your_score(Length_of_snake - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        gameLoop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1_change = -snake_block
                    y1_change = 0
                elif event.key == pygame.K_RIGHT:
                    x1_change = snake_block
                    y1_change = 0
                elif event.key == pygame.K_UP:
                    y1_change = -snake_block
                    x1_change = 0
                elif event.key == pygame.K_DOWN:
                    y1_change = snake_block
                    x1_change = 0

        if x1 >= width or x1 < 0 or y1 >= height or y1 < 0:
            game_close = True

        x1 += x1_change
        y1 += y1_change
        dis.fill(white)
        pygame.draw.rect(dis, green, [foodx, foody, snake_block, snake_block])
        snake_Head = []
        snake_Head.append(x1)
        snake_Head.append(y1)
        snake_List.append(snake_Head)
        if len(snake_List) > Length_of_snake:
            del snake_List[0]

        for x in snake_List[:-1]:
            if x == snake_Head:
                game_close = True

        our_snake(snake_block, snake_List)
        your_score(Length_of_snake - 1)

        pygame.display.update()

        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
            foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0
            Length_of_snake += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()


gameLoop()
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import time
import random

# Initialize pygame
pygame.init()

# Colors
white = (255, 255, 255)
black = (0, 0, 0)
red = (213, 50, 80)
green = (0, 255, 0)
blue = (50, 153, 213)

# Screen dimensions
width = 600
height = 400

# Create game window
dis = pygame.display.set_mode((width, height))
pygame.display.set_caption('Snake Game by Athish')

# Clock & font
clock = pygame.time.Clock()
snake_block = 10
snake_speed = 15
font_style = pygame.font.SysFont("bahnschrift", 25)
score_font = pygame.font.SysFont("comicsansms", 25)


def your_score(score):
    value = score_font.render("Score: " + str(score), True, black)
    dis.blit(value, [10, 10])


def our_snake(snake_block, snake_list):
    for x in snake_list:
        pygame.draw.rect(dis, black, [x[0], x[1], snake_block, snake_block])


def message(msg, color):
    mesg = font_style.render(msg, True, color)
    dis.blit(mesg, [width / 6, height / 3])


def gameLoop():
    game_over = False
    game_close = False

    x1 = width / 2
    y1 = height / 2

    x1_change = 0
    y1_change = 0

    snake_List = []
    Length_of_snake = 1

    foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
    foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0

    while not game_over:

        while game_close:
            dis.fill(blue)
            message("You Lost! Press C-Play Again or Q-Quit", red)
            your_score(Length_of_snake - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        gameLoop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1_change = -snake_block
                    y1_change = 0
                elif event.key == pygame.K_RIGHT:
                    x1_change = snake_block
                    y1_change = 0
                elif event.key == pygame.K_UP:
                    y1_change = -snake_block
                    x1_change = 0
                elif event.key == pygame.K_DOWN:
                    y1_change = snake_block
                    x1_change = 0

        if x1 >= width or x1 < 0 or y1 >= height or y1 < 0:
            game_close = True

        x1 += x1_change
        y1 += y1_change
        dis.fill(white)
        pygame.draw.rect(dis, green, [foodx, foody, snake_block, snake_block])
        snake_Head = []
        snake_Head.append(x1)
        snake_Head.append(y1)
        snake_List.append(snake_Head)
        if len(snake_List) > Length_of_snake:
            del snake_List[0]

        for x in snake_List[:-1]:
            if x == snake_Head:
                game_close = True

        our_snake(snake_block, snake_List)
        your_score(Length_of_snake - 1)

        pygame.display.update()

        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, width - snake_block) / 10.0) * 10.0
            foody = round(random.randrange(0, height - snake_block) / 10.0) * 10.0
            Length_of_snake += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()


gameLoop()
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 129
#     125     pygame.quit()
#     126     quit()
# --> 129 gameLoop()
#
# Cell In[3], line 76, in gameLoop()
#      74                 game_close = False
#      75             if event.key == pygame.K_c:
# ---> 76                 gameLoop()
#      78 for event in pygame.event.get():
#      79     if event.type == pygame.QUIT:
#
# Cell In[3], line 76, in gameLoop()
#      74                 game_close = False
#      75             if event.key == pygame.K_c:
# ---> 76                 gameLoop()
#      78 for event in pygame.event.get():
#      79     if event.type == pygame.QUIT:
#
#     [... skipping similar frames: gameLoop at line 76 (1 times)]
#
# Cell In[3], line 76, in gameLoop()
#      74                 game_close = False
#      75             if event.key == pygame.K_c:
# ---> 76                 gameLoop()
#      78 for event in pygame.event.get():
#      79     if event.type == pygame.QUIT:
#
# Cell In[3], line 65, in gameLoop()
#      62 while not game_over:
#      64     while game_close:
# ---> 65         dis.fill(blue)
#      66         message("You Lost! Press C-Play Again or Q-Quit", red)
#      67         your_score(Length_of_snake - 1)
#
# error: display Surface quit

# %%
import turtle
import time
import random

delay = 0.1
score = 0
high_score = 0

# Set up the screen
wn = turtle.Screen()
wn.title("Snake Game 🐍 - No Walls")
wn.bgcolor("blue")
wn.setup(width=600, height=600)
wn.tracer(0)

# Snake head
head = turtle.Turtle()
head.speed(0)
head.shape("square")
head.color("yellow")
head.penup()
head.goto(0, 0)
head.direction = "stop"

# Food
food = turtle.Turtle()
food.speed(0)
food.shape("circle")
food.color("red")
food.penup()
food.goto(0, 100)

segments = []

# Score display
pen = turtle.Turtle()
pen.speed(0)
pen.color("white")
pen.penup()
pen.hideturtle()
pen.goto(0, 260)
pen.write("Score: 0  High Score: 0", align="center", font=("Courier", 18, "bold"))

# Functions
def go_up():
    if head.direction != "down":
        head.direction = "up"

def go_down():
    if head.direction != "up":
        head.direction = "down"

def go_left():
    if head.direction != "right":
        head.direction = "left"

def go_right():
    if head.direction != "left":
        head.direction = "right"

def move():
    if head.direction == "up":
        y = head.ycor()
        head.sety(y + 20)
    if head.direction == "down":
        y = head.ycor()
        head.sety(y - 20)
    if head.direction == "left":
        x = head.xcor()
        head.setx(x - 20)
    if head.direction == "right":
        x = head.xcor()
        head.setx(x + 20)

    # Wrap around walls instead of dying
    if head.xcor() > 290:
        head.setx(-290)
    elif head.xcor() < -290:
        head.setx(290)
    if head.ycor() > 290:
        head.sety(-290)
    elif head.ycor() < -290:
        head.sety(290)

# Keyboard bindings
wn.listen()
wn.onkeypress(go_up, "w")
wn.onkeypress(go_down, "s")
wn.onkeypress(go_left, "a")
wn.onkeypress(go_right, "d")

# Main game loop
while True:
    wn.update()

    # Check for food collision
    if head.distance(food) < 20:
        x = random.randint(-290, 290)
        y = random.randint(-290, 290)
        food.goto(x, y)

        # Add new segment
        new_segment = turtle.Turtle()
        new_segment.speed(0)
        new_segment.shape("square")
        new_segment.color("yellow")
        new_segment.penup()
        segments.append(new_segment)

        # Increase score
        score += 10
        if score > high_score:
            high_score = score
        pen.clear()
        pen.write(f"Score: {score}  High Score: {high_score}", align="center", font=("Courier", 18, "bold"))

    # Move segments
    for i in range(len(segments) - 1, 0, -1):
        x = segments[i - 1].xcor()
        y = segments[i - 1].ycor()
        segments[i].goto(x, y)

    if len(segments) > 0:
        x = head.xcor()
        y = head.ycor()
        segments[0].goto(x, y)

    move()

    # Check for self-collision
    for segment in segments:
        if segment.distance(head) < 20:
            time.sleep(1)
            head.goto(0, 0)
            head.direction = "stop"

            # Hide segments
            for seg in segments:
                seg.goto(1000, 1000)
            segments.clear()
            score = 0
            pen.clear()
            pen.write(f"Score: {score}  High Score: {high_score}", align="center", font=("Courier", 18, "bold"))

    time.sleep(delay)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 121
#     119     x = segments[i - 1].xcor()
#     120     y = segments[i - 1].ycor()
# --> 121     segments[i].goto(x, y)
#     123 if len(segments) > 0:
#     124     x = head.xcor()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:1775, in TNavigator.goto(self, x, y)
#    1773     self._goto(Vec2D(*x))
#    1774 else:
# -> 1775     self._goto(Vec2D(x, y))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:3230, in RawTurtle._goto(self, end)
#    3222 go_modes = ( self._drawing,
#    3223              self._pencolor,
#    3224              self._pensize,
#    3225              isinstance(self._fillpath, list))
#    3226 screen = self.screen
#    3227 undo_entry = ("go", self._position, end, go_modes,
#    3228               (self.currentLineItem,
#    3229               self.currentLine[:],
# -> 3230               screen._pointlist(self.currentLineItem),
#    3231               self.items[:])
#    3232               )
#    3233 if self.undobuffer:
#    3234     self.undobuffer.push(undo_entry)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:745, in TurtleScreenBase._pointlist(self, item)
#     737 def _pointlist(self, item):
#     738     """returns list of coordinate-pairs of points of item
#     739     Example (for insiders):
#     740     >>> from turtle import *
#    (...)    743     (9.9999999999999982, 0.0)]
#     744     >>> """
# --> 745     cl = self.cv.coords(item)
#     746     pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     747     return  pl
#
# File <string>:1, in coords(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:2853, in Canvas.coords(self, *args)
#    2849 """Return a list of coordinates for the item given in ARGS."""
#    2850 args = _flatten(args)
#    2851 return [self.tk.getdouble(x) for x in
#    2852                    self.tk.splitlist(
# -> 2853            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"

# %%
import pygame
import random

# Initialize pygame
pygame.init()

# Colors
light_green = (144, 238, 144)
yellow = (255, 255, 0)
red = (255, 0, 0)
black = (0, 0, 0)

# Screen dimensions
width = 600
height = 400

# Snake settings
block_size = 20
snake_speed = 15

# Create window
win = pygame.display.set_mode((width, height))
pygame.display.set_caption("Snake Game - Classic Wrap")

clock = pygame.time.Clock()
font = pygame.font.SysFont(None, 35)

def draw_snake(snake_list):
    for x in snake_list:
        pygame.draw.rect(win, yellow, [x[0], x[1], block_size, block_size])

def show_score(score):
    value = font.render(f"Score: {score}", True, black)
    win.blit(value, [10, 10])

def game_loop():
    game_over = False
    game_close = False

    x = width / 2
    y = height / 2
    x_change = 0
    y_change = 0

    snake_list = []
    snake_length = 1

    foodx = round(random.randrange(0, width - block_size) / 20.0) * 20.0
    foody = round(random.randrange(0, height - block_size) / 20.0) * 20.0

    while not game_over:

        while game_close:
            win.fill(light_green)
            msg = font.render("You Lost! Press C to Play Again or Q to Quit", True, red)
            win.blit(msg, [width / 12, height / 3])
            show_score(snake_length - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        game_loop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x_change = -block_size
                    y_change = 0
                elif event.key == pygame.K_RIGHT:
                    x_change = block_size
                    y_change = 0
                elif event.key == pygame.K_UP:
                    y_change = -block_size
                    x_change = 0
                elif event.key == pygame.K_DOWN:
                    y_change = block_size
                    x_change = 0

        # Wrap-around movement
        x = (x + x_change) % width
        y = (y + y_change) % height

        win.fill(light_green)
        pygame.draw.rect(win, red, [foodx, foody, block_size, block_size])

        snake_head = [x, y]
        snake_list.append(snake_head)
        if len(snake_list) > snake_length:
            del snake_list[0]

        for part in snake_list[:-1]:
            if part == snake_head:
                game_close = True

        draw_snake(snake_list)
        show_score(snake_length - 1)
        pygame.display.update()

        if x == foodx and y == foody:
            foodx = round(random.randrange(0, width - block_size) / 20.0) * 20.0
            foody = round(random.randrange(0, height - block_size) / 20.0) * 20.0
            snake_length += 1

        clock.tick(snake_speed)

    pygame.quit()
    quit()

game_loop()
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import random

# Initialize pygame
pygame.init()

# Colors
light_green = (144, 238, 144)
yellow = (255, 255, 0)
red = (255, 0, 0)
black = (0, 0, 0)

# Screen dimensions
width = 600
height = 400

# Snake settings
block_size = 20
snake_speed = 15

# Create window
win = pygame.display.set_mode((width, height))
pygame.display.set_caption("Snake Game - Classic Wrap")

clock = pygame.time.Clock()
font = pygame.font.SysFont(None, 35)

def draw_snake(snake_list):
    for x in snake_list:  
        pygame.draw.rect(win, yellow, [x[0], x[1], block_size, block_size])

def show_score(score):
    value = font.render(f"Score: {score}", True, black)
    win.blit(value, [10, 10])

def game_loop():
    game_over = False
    game_close = False

    x = width / 3
    y = height / 5
    x_change = 0
    y_change = 0
    snake_list = []
    snake_length = 1

    foodx = round(random.randrange(0, width - block_size) / 20.0) * 20.0
    foody = round(random.randrange(0, height - block_size) / 20.0) * 20.0

    while not game_over:

        while game_close:
            win.fill(light_green)
            msg = font.render("You Lost! Press C to Play Again or Q to Quit", True, red)
            win.blit(msg, [width / 12, height / 3])
            show_score(snake_length - 1)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False
                    if event.key == pygame.K_c:
                        game_loop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pass
            elif event.type == pygame.KEYDOWN:
                # prevent 180-degree reverse
                if event.key == pygame.K_LEFT and x_change != block_size:
                    x_change = -block_size
                    y_change = 0
                elif event.key == pygame.K_RIGHT and x_change != -block_size:
                    x_change = block_size
                    y_change = 0
                elif event.key == pygame.K_UP and y_change != block_size:
                    y_change = -block_size
                    x_change = 0
                elif event.key == pygame.K_DOWN and y_change != -block_size:
                    y_change = block_size
                    x_change = 0

        # Wrap-around movement
        x = (x + x_change) % width
        y = (y + y_change) % height

        win.fill(light_green)
        pygame.draw.rect(win, red, [foodx, foody, block_size, block_size])

        snake_head = [x, y]
        snake_list.append(snake_head)
        if len(snake_list) > snake_length:
            del snake_list[0]

        # Collision with itself
        for part in snake_list[:-1]:
            if snake_head == part:
                game_close = True

        draw_snake(snake_list)
        show_score(snake_length - 1)
        pygame.display.update()

        # Eating food
        if x == foodx and y == foody:
            foodx = round(random.randrange(0, width - block_size) / 20.0) * 20.0
            foody = round(random.randrange(0, height - block_size) / 20.0) * 20.0
            snake_length += 1

        clock.tick(snake_speed)
so the nsake movement is based
    pygame.quit()
    quit()

game_loop()
# Out:
# C:\Users\sampar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
